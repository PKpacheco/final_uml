# %% [markdown]
# # COMP-3705 (241553) Unsupervised Machine Learning
# ## Project: Topic Modeling
# Group 8:
# * Paola Katherine Pacheco
# * Wai Ping Kwok
# * Xueyao Wang

# %% [markdown]
# **Objective:**
#
# To find a use case for topic modeling, then source the data and develop code to address the use case; to provide a written explanation of what is done along with an executive summary and conclusion.

# %% [markdown]
# **Problem Statement:**
#
# You are to develop your own use case for topic modeling. It should concern text data that you are interested in and be realistic for a data scientist or machine learning developer.

# %% [markdown]
# **Data:**
#
# Obtained from BBC News Classification | Kaggle https://www.kaggle.com/competitions/learn-ai-bbc

# %% [markdown]
# **Steps to Completion:**
#
# Develop one or more Jupyter notebook(s) containing code and written content in markdown. The notebook(s) should contain the sections listed below, indicated with clear headings. Where coding is done, provide comments to explain how it works. Develop this project as if you are creating it for important stakeholders connected to the use case.

# %% [markdown]
# # **Executive Summary:**
#
# Our project is to apply topic modelling to news classification, which has many applications, such as personalized news feeds, targeted advertising, and news trend analysis. The BBC news dataset has 1490 records across 5 categories: business, entertainment, politics, sport, and tech. The preprocessing includes removing stop words, non-English words, and words less than 5 characters, removing punctuation, standardizing case, lemmatizing, and tokenizing. We develop 6 LDA models and 6 NMF models and experiment with various hyperparameters, such as the number of features, maximum document frequency, minimum document frequency, etc. Given that our dataset is relatively small, we tend to choose smaller numbers for the above hyperparameters.
#
# The best LDA model is model 4, as it achieves a low perplexity and each bubble shown in the pyLDAvis has a reasonable size and distinct circle. This model best addresses our use case as it accurately classifies news articles into 5 categories, and the topic words found in the word-topic table align with the 5 topics in the original dataset. The word-topic tables show that the abstract topics for the business category include words like 'software' and 'Microsoft', which may suggest that giant software companies like Microsoft are closely related to business news. (200)

# %% [markdown]
# ### Environment Preparation

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (1.9.2)
# Requirement already satisfied: pillow in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from wordcloud) (9.5.0)
# Requirement already satisfied: matplotlib in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from wordcloud) (3.5.3)
# Requirement already satisfied: numpy>=1.6.1 in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from wordcloud) (1.21.6)
# Requirement already satisfied: pyparsing>=2.2.1 in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from matplotlib->wordcloud) (22.0)
# Requirement already satisfied: typing-extensions in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib->wordcloud) (4.3.0)
# Requirement already satisfied: six>=1.5 in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
# to check the version of the packages under the environment
# !pip list
# Out:
# Package              Version
# -------------------- -----------
# anyio                3.5.0
# appnope              0.1.2
# argon2-cffi          20.1.0
# attrs                22.1.0
# Babel                2.11.0
# backcall             0.2.0
# beautifulsoup4       4.11.1
# bleach               4.1.0
# brotlipy             0.7.0
# certifi              2022.12.7
# cffi                 1.15.1
# charset-normalizer   2.0.4
# click                8.1.7
# cryptography         39.0.1
# cycler               0.11.0
# debugpy              1.5.1
# decorator            5.1.1
# defusedxml           0.7.1
# entrypoints          0.4
# fastjsonschema       2.16.2
# fonttools            4.38.0
# funcy                2.0
# future               0.18.3
# gensim               4.2.0
# idna                 3.4
# importlib-metadata   4.11.3
# importlib-resources  5.2.0
# ipykernel            6.15.2
# ipython              7.31.1
# ipython-genutils     0.2.0
# jedi                 0.18.1
# Jinja2               3.1.2
# joblib               1.3.2
# json5                0.9.6
# jsonschema           4.17.3
# jupyter_client       7.4.9
# jupyter_core         4.11.2
# jupyter-server       1.23.4
# jupyterlab           3.5.3
# jupyterlab-pygments  0.1.2
# jupyterlab_server    2.19.0
# kiwisolver           1.4.5
# langdetect           1.0.9
# MarkupSafe           2.1.1
# matplotlib           3.5.3
# matplotlib-inline    0.1.6
# mistune              0.8.4
# nbclassic            0.5.2
# nbclient             0.5.13
# nbconvert            6.4.4
# nbformat             5.7.0
# nest-asyncio         1.5.6
# nltk                 3.8.1
# notebook             6.5.2
# notebook_shim        0.2.2
# numexpr              2.8.6
# numpy                1.21.6
# packaging            22.0
# pandas               1.3.5
# pandocfilters        1.5.0
# parso                0.8.3
# pexpect              4.8.0
# pickleshare          0.7.5
# Pillow               9.5.0
# pip                  22.3.1
# pkgutil_resolve_name 1.3.10
# plotly               5.18.0
# prettytable          3.7.0
# prometheus-client    0.14.1
# prompt-toolkit       3.0.36
# psutil               5.9.0
# ptyprocess           0.7.0
# pycparser            2.21
# Pygments             2.11.2
# pyLDAvis             3.3.1
# pyOpenSSL            23.0.0
# pyparsing            3.1.1
# pyrsistent           0.18.0
# PySocks              1.7.1
# python-dateutil      2.8.2
# pytz                 2022.7
# pyzmq                23.2.0
# regex                2023.10.3
# requests             2.28.1
# scikit-learn         1.0.2
# scipy                1.7.3
# Send2Trash           1.8.0
# setuptools           65.6.3
# six                  1.16.0
# sklearn              0.0.post11
# smart-open           6.4.0
# sniffio              1.2.0
# soupsieve            2.3.2.post1
# tenacity             8.2.3
# terminado            0.17.1
# testpath             0.6.0
# threadpoolctl        3.1.0
# tomli                2.0.1
# tornado              6.2
# tqdm                 4.66.1
# traitlets            5.7.1
# typing_extensions    4.3.0
# urllib3              1.26.14
# wcwidth              0.2.5
# webencodings         0.5.1
# websocket-client     0.58.0
# wheel                0.38.4
# wordcloud            1.9.2
# zipp                 3.11.0

# %%
pip install pyLDAvis scikit-learn
# Out:
# Requirement already satisfied: pyLDAvis in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (3.3.1)
# Requirement already satisfied: scikit-learn in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (1.0.2)
# Requirement already satisfied: numexpr in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from pyLDAvis) (2.8.6)
# Requirement already satisfied: pandas>=1.2.0 in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from pyLDAvis) (1.3.5)
# Requirement already satisfied: future in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from pyLDAvis) (0.18.3)
# Requirement already satisfied: gensim in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from pyLDAvis) (4.2.0)
# Requirement already satisfied: setuptools in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from pyLDAvis) (65.6.3)
# Requirement already satisfied: jinja2 in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from pyLDAvis) (3.1.2)
# Requirement already satisfied: numpy>=1.20.0 in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from pyLDAvis) (1.21.6)
# Requirement already satisfied: funcy in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: scipy in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from pyLDAvis) (1.7.3)
# Requirement already satisfied: joblib in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from pyLDAvis) (1.3.2)
# Requirement already satisfied: sklearn in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from pyLDAvis) (0.0.post11)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: pytz>=2017.3 in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from pandas>=1.2.0->pyLDAvis) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: smart-open>=1.8.1 in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from gensim->pyLDAvis) (6.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from jinja2->pyLDAvis) (2.1.1)
# Requirement already satisfied: six>=1.5 in ./opt/anaconda3/envs/python37/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import libraries
import langdetect  # language detection
import matplotlib.pyplot as plt  # plotting
import numpy as np  # arrays and matrices
import nltk  # natural language processing
import pandas as pd  # dataframes
import regex as re # regular expressions
from time import time # track time
from prettytable import PrettyTable # table formatting

import pyLDAvis  # plotting

# import pyLDAvis.sklearn  # plotting
# import pyLDAvis.lda_model  # plotting

import sklearn  # machine learning
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF
from sklearn.manifold import TSNE
from sklearn.metrics import mean_squared_error

from wordcloud import WordCloud

import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
# installing specific word dictionarys
# used for stopword removal and lemmatization
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/paolakatherine/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/paolakatherine/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # **Preprocessing:**
#
# Develop code to prepare the data for LDA and NMF topic modeling as we have done in class. This includes cleaning, standardizing case, lemmatizing, removing stop words, and tokenizing.

# %%
url_bbc ="https://raw.githubusercontent.com/PKpacheco/final_uml/main/BBC%20News%20Train.csv"

# %%
# load the data
df = pd.read_csv(url_bbc)
df.head()
# Out:
#    ArticleId                                               Text  Category
# 0       1833  worldcom ex-boss launches defence lawyers defe...  business
# 1        154  german business confidence slides german busin...  business
# 2       1101  bbc poll indicates economic gloom citizens in ...  business
# 3       1976  lifestyle  governs mobile choice  faster  bett...      tech
# 4        917  enron bosses in $168m payout eighteen former e...  business

# %%
# define a quick look function for data frame
def dataframe_quick_look(df, nrows):
    print("SHAPE:\n{shape}\n".format(shape=df.shape))
    print("COLUMN NAMES:\n{names}\n".format(names=df.columns))
    print("HEAD:\n{head}\n".format(head=df.head(nrows)))

# %%
# test the function
dataframe_quick_look(df, nrows=2)
# Out:
# SHAPE:
# (1490, 3)
#
# COLUMN NAMES:
# Index(['ArticleId', 'Text', 'Category'], dtype='object')
#
# HEAD:
#    ArticleId                                               Text  Category
# 0       1833  worldcom ex-boss launches defence lawyers defe...  business
# 1        154  german business confidence slides german busin...  business

# %%
# data set came with prespecified topics
# print the topics out with counts
df["Category"].value_counts()
# Out:
# sport            346
# business         336
# politics         274
# entertainment    273
# tech             261
# Name: Category, dtype: int64

# %%
# visualize the topic counts by percentage in a pie chart
plt.figure(figsize=(6, 6))
plt.pie(df["Category"].value_counts(), labels=df["Category"].value_counts().index, autopct='%1.1f%%')
plt.title("Topic Counts")
plt.show()

# %% [markdown]
# **Observation**
#
# We can see that toplics such as politcs, entertainment, and tech have roughtly 4% less representations then business and sport. It is comparatively balanced dataset.

# %%
# view final data that will be carried forward
raw = df['Text'].tolist()
print("NEWS:\n{lines}\n".format(lines=raw[:2]))
print("LENGTH:\n{length}\n".format(length=len(raw)))
# Out:
# NEWS:
# ['worldcom ex-boss launches defence lawyers defending former worldcom chief bernie ebbers against a battery of fraud charges have called a company whistleblower as their first witness.  cynthia cooper  worldcom s ex-head of internal accounting  alerted directors to irregular accounting practices at the us telecoms giant in 2002. her warnings led to the collapse of the firm following the discovery of an $11bn (£5.7bn) accounting fraud. mr ebbers has pleaded not guilty to charges of fraud and conspiracy.  prosecution lawyers have argued that mr ebbers orchestrated a series of accounting tricks at worldcom  ordering employees to hide expenses and inflate revenues to meet wall street earnings estimates. but ms cooper  who now runs her own consulting business  told a jury in new york on wednesday that external auditors arthur andersen had approved worldcom s accounting in early 2001 and 2002. she said andersen had given a  green light  to the procedures and practices used by worldcom. mr ebber s lawyers have said he was unaware of the fraud  arguing that auditors did not alert him to any problems.  ms cooper also said that during shareholder meetings mr ebbers often passed over technical questions to the company s finance chief  giving only  brief  answers himself. the prosecution s star witness  former worldcom financial chief scott sullivan  has said that mr ebbers ordered accounting adjustments at the firm  telling him to  hit our books . however  ms cooper said mr sullivan had not mentioned  anything uncomfortable  about worldcom s accounting during a 2001 audit committee meeting. mr ebbers could face a jail sentence of 85 years if convicted of all the charges he is facing. worldcom emerged from bankruptcy protection in 2004  and is now known as mci. last week  mci agreed to a buyout by verizon communications in a deal valued at $6.75bn.', 'german business confidence slides german business confidence fell in february knocking hopes of a speedy recovery in europe s largest economy.  munich-based research institute ifo said that its confidence index fell to 95.5 in february from 97.5 in january  its first decline in three months. the study found that the outlook in both the manufacturing and retail sectors had worsened. observers had been hoping that a more confident business sector would signal that economic activity was picking up.   we re surprised that the ifo index has taken such a knock   said dz bank economist bernd weidensteiner.  the main reason is probably that the domestic economy is still weak  particularly in the retail trade.  economy and labour minister wolfgang clement called the dip in february s ifo confidence figure  a very mild decline . he said that despite the retreat  the index remained at a relatively high level and that he expected  a modest economic upswing  to continue.  germany s economy grew 1.6% last year after shrinking in 2003. however  the economy contracted by 0.2% during the last three months of 2004  mainly due to the reluctance of consumers to spend. latest indications are that growth is still proving elusive and ifo president hans-werner sinn said any improvement in german domestic demand was sluggish. exports had kept things going during the first half of 2004  but demand for exports was then hit as the value of the euro hit record levels making german products less competitive overseas. on top of that  the unemployment rate has been stuck at close to 10% and manufacturing firms  including daimlerchrysler  siemens and volkswagen  have been negotiating with unions over cost cutting measures. analysts said that the ifo figures and germany s continuing problems may delay an interest rate rise by the european central bank. eurozone interest rates are at 2%  but comments from senior officials have recently focused on the threat of inflation  prompting fears that interest rates may rise.']
#
# LENGTH:
# 1490

# %%
# define function for checking language of test
# filter to english only
def do_language_identifying(txt):
    try:
       the_language = langdetect.detect(txt)
    except:
       the_language = 'none'
    return the_language

# %%
# define function to perform lemmatization
def do_lemmatizing(wrd):
    out = nltk.corpus.wordnet.morphy(wrd)
    return (wrd if out is None else out)

# %%
# more stop words to remove
stop_words_news = pd.read_csv('https://raw.githubusercontent.com/vikasing/news-stopwords/master/sw1k.csv')
stop_words_news_list = stop_words_news['term'].to_list()
stop_words_news_list
# Out:
# ['the',
#  'to',
#  'and',
#  'of',
#  'a',
#  'in',
#  'on',
#  'for',
#  's',
#  'is',
#  'with',
#  'that',
#  'at',
#  'by',
#  'it',
#  'as',
#  'from',
#  'was',
#  'be',
#  'has',
#  'an',
#  'this',
#  'have',
#  'are',
#  'not',
#  'said',
#  'but',
#  'will',
#  'he',
#  'who',
#  'been',
#  'after',
#  'their',
#  'one',
#  'which',
#  'they',
#  'his',
#  'up',
#  'also',
#  'more',
#  'all',
#  'about',
#  'or',
#  'we',
#  'out',
#  'had',
#  'year',
#  'were',
#  'new',
#  'when',
#  't',
#  'there',
#  'two',
#  'you',
#  'over',
#  'its',
#  'can',
#  'would',
#  'first',
#  'time',
#  'last',
#  'if',
#  'other',
#  'than',
#  'i',
#  'no',
#  'into',
#  'so',
#  'some',
#  'people',
#  'what',
#  'while',
#  'just',
#  'could',
#  'now',
#  'years',
#  'like',
#  'get',
#  'only',
#  'our',
#  'them',
#  'before',
#  'most',
#  'may',
#  'being',
#  'do',
#  'three',
#  'make',
#  'any',
#  'day',
#  'made',
#  'how',
#  'back',
#  'us',
#  'during',
#  'where',
#  '1',
#  'against',
#  'even',
#  'because',
#  'your',
#  'since',
#  'many',
#  'off',
#  'she',
#  'him',
#  'her',
#  'take',
#  'through',
#  'well',
#  'world',
#  'told',
#  'down',
#  'then',
#  'including',
#  'state',
#  'way',
#  '10',
#  'president',
#  'those',
#  '2',
#  'under',
#  '2017',
#  'old',
#  'government',
#  'such',
#  'still',
#  'between',
#  'these',
#  'week',
#  'much',
#  'around',
#  'home',
#  'should',
#  'according',
#  'another',
#  'long',
#  'go',
#  'very',
#  'here',
#  'news',
#  'see',
#  'both',
#  'did',
#  're',
#  'high',
#  'say',
#  'says',
#  'next',
#  'part',
#  'going',
#  'work',
#  '3',
#  'don',
#  'good',
#  '5',
#  'four',
#  'right',
#  'country',
#  '000',
#  'my',
#  'top',
#  'come',
#  'm',
#  'set',
#  'former',
#  'end',
#  'need',
#  'know',
#  'national',
#  'help',
#  'five',
#  '2015',
#  '4',
#  'want',
#  'same',
#  'second',
#  'best',
#  'called',
#  'think',
#  'public',
#  'today',
#  'left',
#  'times',
#  'team',
#  'use',
#  'later',
#  'without',
#  'life',
#  'city',
#  '20',
#  'too',
#  'every',
#  'however',
#  'days',
#  'group',
#  'media',
#  'place',
#  'month',
#  'own',
#  'big',
#  'man',
#  'house',
#  'took',
#  'put',
#  'used',
#  'found',
#  '12',
#  'march',
#  'photo',
#  'few',
#  '6',
#  'minister',
#  'police',
#  'me',
#  'again',
#  'added',
#  'show',
#  'million',
#  'family',
#  'u',
#  'based',
#  'look',
#  'away',
#  'never',
#  'april',
#  '30',
#  'making',
#  'got',
#  'came',
#  'chief',
#  '7',
#  'friday',
#  'far',
#  'across',
#  'business',
#  'won',
#  '2016',
#  '15',
#  'among',
#  'number',
#  'company',
#  'months',
#  'past',
#  'each',
#  'already',
#  'support',
#  'trump',
#  '8',
#  'six',
#  'better',
#  've',
#  'seen',
#  'little',
#  'several',
#  'night',
#  'monday',
#  'really',
#  'great',
#  'tuesday',
#  'case',
#  'early',
#  'taken',
#  'asked',
#  'point',
#  'office',
#  'why',
#  'might',
#  '11',
#  'least',
#  'run',
#  'saying',
#  'start',
#  'whether',
#  'things',
#  'wednesday',
#  'give',
#  'does',
#  'd',
#  'lot',
#  'per',
#  'united',
#  'find',
#  'information',
#  'earlier',
#  'states',
#  'following',
#  'thursday',
#  'yet',
#  'international',
#  'didn',
#  'something',
#  'once',
#  'party',
#  'known',
#  'recent',
#  'though',
#  'court',
#  'taking',
#  'must',
#  'report',
#  'com',
#  'less',
#  'major',
#  'given',
#  'become',
#  'ago',
#  'local',
#  'working',
#  'hit',
#  'having',
#  'expected',
#  'went',
#  'keep',
#  'third',
#  'change',
#  'u.s.',
#  'officials',
#  'until',
#  'full',
#  '9',
#  'open',
#  'head',
#  'south',
#  'sunday',
#  'free',
#  'american',
#  'india',
#  'play',
#  'security',
#  'using',
#  'different',
#  'game',
#  'statement',
#  'always',
#  'move',
#  'others',
#  'reported',
#  'along',
#  'led',
#  'power',
#  'director',
#  'behind',
#  'money',
#  'donald',
#  'market',
#  'white',
#  'members',
#  'held',
#  'post',
#  'able',
#  'published',
#  'close',
#  'getting',
#  'looking',
#  'comes',
#  'political',
#  'likely',
#  'face',
#  'saturday',
#  'area',
#  'win',
#  'star',
#  'story',
#  'future',
#  'north',
#  'll',
#  '50',
#  'half',
#  'hard',
#  'live',
#  'further',
#  '25',
#  'law',
#  'share',
#  'try',
#  'near',
#  'press',
#  'deal',
#  'season',
#  'ever',
#  'coming',
#  '18',
#  'donald trump',
#  'late',
#  'despite',
#  'real',
#  'daily',
#  '16',
#  'am',
#  'line',
#  'doesn',
#  'general',
#  'video',
#  'enough',
#  'washington',
#  'within',
#  'social',
#  'important',
#  'system',
#  'school',
#  'trying',
#  'side',
#  'latest',
#  'leader',
#  'started',
#  'young',
#  'service',
#  'due',
#  '2014',
#  'call',
#  'order',
#  'done',
#  'almost',
#  'clear',
#  'rights',
#  '100',
#  'department',
#  'small',
#  'health',
#  'doing',
#  'women',
#  'decision',
#  'announced',
#  'children',
#  'twitter',
#  'continue',
#  'final',
#  'lead',
#  'campaign',
#  'lost',
#  'plan',
#  '17',
#  'co',
#  'west',
#  'name',
#  '14',
#  'seven',
#  'services',
#  'official',
#  'issue',
#  'thing',
#  'recently',
#  'prime',
#  'january',
#  'action',
#  'policy',
#  'ahead',
#  '13',
#  'percent',
#  'outside',
#  'person',
#  'nearly',
#  'together',
#  'hours',
#  'university',
#  'possible',
#  'pay',
#  'death',
#  'let',
#  'community',
#  'plans',
#  'morning',
#  'senior',
#  'large',
#  'front',
#  'role',
#  'weeks',
#  'john',
#  'reports',
#  'believe',
#  'meeting',
#  'sure',
#  'often',
#  'level',
#  'york',
#  'released',
#  'election',
#  'fact',
#  'soon',
#  'strong',
#  'series',
#  'makes',
#  'online',
#  'key',
#  'men',
#  'history',
#  'attack',
#  'comments',
#  'job',
#  'woman',
#  'current',
#  'agency',
#  'whose',
#  '24',
#  'provide',
#  'shows',
#  'biggest',
#  'killed',
#  'nation',
#  'foreign',
#  'center',
#  'companies',
#  'love',
#  'executive',
#  'feel',
#  'issues',
#  'low',
#  'instead',
#  'war',
#  'site',
#  'access',
#  'process',
#  'leaders',
#  'record',
#  'comment',
#  'david',
#  'stop',
#  'control',
#  'eight',
#  'central',
#  'federal',
#  'bring',
#  'forward',
#  'thought',
#  'received',
#  '40',
#  'personal',
#  'act',
#  'wanted',
#  'return',
#  'nothing',
#  'needs',
#  'mark',
#  'special',
#  '19',
#  'include',
#  'read',
#  'global',
#  'industry',
#  'means',
#  'private',
#  'capital',
#  '2013',
#  'street',
#  'available',
#  'began',
#  'course',
#  'administration',
#  '21',
#  'please',
#  'bill',
#  'short',
#  'staff',
#  'china',
#  'interest',
#  'saw',
#  'financial',
#  'billion',
#  'leave',
#  'air',
#  'mr',
#  'development',
#  'hand',
#  'follow',
#  'board',
#  'experience',
#  'everyone',
#  'matter',
#  'term',
#  'although',
#  'car',
#  'care',
#  'countries',
#  'event',
#  'building',
#  '22',
#  'kind',
#  'force',
#  'higher',
#  'australia',
#  'america',
#  'wants',
#  'especially',
#  'cost',
#  'anything',
#  'member',
#  'currently',
#  'bit',
#  'played',
#  'leading',
#  'himself',
#  'shot',
#  'meet',
#  'february',
#  'east',
#  'problem',
#  'everything',
#  'economic',
#  'data',
#  'points',
#  'isn',
#  'running',
#  'body',
#  'indian',
#  'sign',
#  'hope',
#  'united states',
#  'turned',
#  'inside',
#  'research',
#  'sent',
#  'visit',
#  '0',
#  'turn',
#  'wasn',
#  'gave',
#  'became',
#  'players',
#  'rather',
#  'watch',
#  'secretary',
#  'road',
#  'question',
#  'died',
#  'black',
#  'wrote',
#  'ap',
#  'involved',
#  'actually',
#  'room',
#  'potential',
#  'cut',
#  'december',
#  'hold',
#  '23',
#  'needed',
#  'someone',
#  'p',
#  'list',
#  'popular',
#  'bank',
#  'takes',
#  'stay',
#  'brought',
#  'union',
#  'lives',
#  'tv',
#  'similar',
#  'form',
#  'showed',
#  'images',
#  'fight',
#  'terms',
#  'human',
#  'conference',
#  'playing',
#  'total',
#  'result',
#  'bad',
#  'price',
#  'friends',
#  'single',
#  'related',
#  '28',
#  'note',
#  'military',
#  'delhi',
#  'nine',
#  'huge',
#  'minutes',
#  'games',
#  'facebook',
#  'obama',
#  'technology',
#  'food',
#  'pm',
#  'couple',
#  'officer',
#  'increase',
#  'largest',
#  'michael',
#  'account',
#  'offer',
#  'authorities',
#  'park',
#  'growth',
#  'either',
#  'view',
#  'release',
#  'address',
#  'previous',
#  'chance',
#  'living',
#  'idea',
#  'middle',
#  'cent',
#  'talk',
#  'position',
#  'email',
#  '500',
#  'age',
#  'remain',
#  'red',
#  'associated',
#  'network',
#  'mother',
#  'round',
#  'league',
#  'above',
#  'non',
#  'moment',
#  'reason',
#  'period',
#  'helped',
#  '27',
#  'program',
#  'problems',
#  'growing',
#  'anyone',
#  'career',
#  'allow',
#  'thousands',
#  'main',
#  'worked',
#  'fans',
#  'subscribe',
#  'trade',
#  'reuters',
#  'content',
#  'lower',
#  'investigation',
#  'focus',
#  'risk',
#  'australian',
#  'limited',
#  'water',
#  'tell',
#  'project',
#  'ground',
#  'stand',
#  'cannot',
#  'tried',
#  'step',
#  'son',
#  'decided',
#  'longer',
#  'wife',
#  'film',
#  'legal',
#  'district',
#  'probably',
#  'article',
#  'situation',
#  'adding',
#  'fire',
#  'areas',
#  'seems',
#  '26',
#  'themselves',
#  'posted',
#  'details',
#  'james',
#  'create',
#  'interview',
#  'happened',
#  'committee',
#  'whole',
#  'london',
#  'difficult',
#  'looks',
#  'spent',
#  'launched',
#  'tax',
#  'accused',
#  'hospital',
#  'pressure',
#  'paid',
#  'match',
#  'changes',
#  'reached',
#  'anti',
#  'father',
#  'efforts',
#  'remains',
#  'town',
#  'ready',
#  'club',
#  '2012',
#  'failed',
#  'response',
#  'met',
#  'test',
#  'new york',
#  'council',
#  'directly',
#  'questions',
#  'light',
#  'june',
#  'groups',
#  'county',
#  'happy',
#  'centre',
#  'break',
#  'november',
#  'performance',
#  'region',
#  'loss',
#  'winning',
#  'giving',
#  'claims',
#  'serious',
#  'annual',
#  'rate',
#  'field',
#  'economy',
#  'british',
#  'phone',
#  'congress',
#  'example',
#  '29',
#  'build',
#  'gone',
#  'space',
#  '60',
#  'dead',
#  'website',
#  'weekend',
#  'worth',
#  'opportunity',
#  'land',
#  'vote',
#  'impact',
#  'revealed',
#  'stage',
#  'itself',
#  'followed',
#  'incident',
#  'gets',
#  'talks',
#  'claimed',
#  'child',
#  'rest',
#  'chairman',
#  'finally',
#  'allowed',
#  'immediately',
#  'summer',
#  'decades',
#  'quite',
#  'fourth',
#  'included',
#  'spokesman',
#  'goes',
#  'opening',
#  'results',
#  'stories',
#  'e',
#  'st',
#  'player',
#  'ended',
#  'digital',
#  'n',
#  'c',
#  'reach',
#  'fall',
#  'updated',
#  'ways',
#  'significant',
#  'raised',
#  'date',
#  'understand',
#  'starting',
#  'heard',
#  'named',
#  'speaking',
#  'easy',
#  'jobs',
#  'manager',
#  'calls',
#  'simple',
#  'hour',
#  'works',
#  'moved',
#  'leaving',
#  'energy',
#  'continued',
#  'rules',
#  'justice',
#  'jan',
#  '31',
#  'investment',
#  'average',
#  '200',
#  'ask',
#  'victory',
#  'students',
#  'heart',
#  'evidence',
#  'rise',
#  'european',
#  'class',
#  'created',
#  'forces',
#  'safety',
#  'articles',
#  'concerns',
#  'prices',
#  'hands',
#  'true',
#  'quickly',
#  'charge',
#  'appeared',
#  'ensure',
#  'medical',
#  'self',
#  'various',
#  'confirmed',
#  'mean',
#  'certain',
#  'message',
#  'workers',
#  'happen',
#  'goal',
#  'meanwhile',
#  'felt',
#  'check',
#  'wrong',
#  'white house',
#  'budget',
#  'presidential',
#  'sense',
#  'expect',
#  'arrested',
#  'below',
#  'opposition',
#  'thank',
#  'facing',
#  'amount',
#  'attacks',
#  'range',
#  'parents',
#  'russia',
#  'drive',
#  'provided',
#  'described',
#  'buy',
#  'politics',
#  'forced',
#  'beyond',
#  'sales',
#  'includes',
#  'management',
#  'challenge',
#  'mind',
#  'effort',
#  'attention',
#  'calling',
#  'cause',
#  'events',
#  'via',
#  'talking',
#  'parties',
#  'changed',
#  'moving',
#  'towards',
#  'study',
#  'entire',
#  'europe',
#  'opened',
#  'quarter',
#  'value',
#  'relationship',
#  '35',
#  'firm',
#  'success',
#  'book',
#  'chinese',
#  'charges',
#  'o',
#  'issued',
#  'join',
#  'july',
#  'september',
#  'image',
#  'views',
#  'pretty',
#  'wall',
#  'civil',
#  'present',
#  '2011',
#  'particularly',
#  'built',
#  'else',
#  'travel',
#  'officers',
#  'seeking',
#  'paul',
#  'fell',
#  'demand']

# %%
# define function to cleaning text data

def do_text_cleaning(txt):
    # identify language of text
    # return null if language not english
    lg = do_language_identifying(txt)
    if lg != 'en':
        return None

    # split the string on whitespace
    out = txt.split(' ')

    # identify screen names
    # replace with SCREENNAME
    out = ['SCREENNAME' if i.startswith('@') else i for i in out]

    # identify urls
    # replace with URL
    out = [
        'URL' if bool(re.search('http[s]?://', i))
        else i for i in out
    ]

    # remove all punctuation
    out = [re.sub('[^\\w\\s]|\n', '', i) for i in out]

    # make all non-keywords lowercase
    keys = ['SCREENNAME', 'URL']
    out = [i.lower() if i not in keys else i for i in out]

    # remove keywords
    out = [i for i in out if i not in keys]

    # remove stopwords
    stop_words = nltk.corpus.stopwords.words('english')
    list_stop_words = stop_words + stop_words_news_list
    list_stop_words = [re.sub('[^\\w\\s]', '', i) for i in list_stop_words]
    out = [i for i in out if i not in list_stop_words]

    # lemmatizing
    out = [do_lemmatizing(i) for i in out]

    # keep words 4 or more characters long
    out = [i for i in out if len(i) >= 5]

    return out

# %%
# apply cleaning function to every tweet
tick = time()
clean = list(map(do_text_cleaning, raw))
print(time()-tick)
# Out:
# 37.632670164108276

# %%
# remove none types
clean = list(filter(None.__ne__, clean))
print("NEWS:\n{lines}\n".format(lines=clean[:2]))
print("LENGTH:\n{length}\n".format(length=len(clean)))
# Out:
# NEWS:
# [['worldcom', 'exboss', 'launch', 'defence', 'lawyer', 'defend', 'worldcom', 'bernie', 'ebbers', 'battery', 'fraud', 'whistleblower', 'witness', 'cynthia', 'cooper', 'worldcom', 'exhead', 'internal', 'accounting', 'alert', 'director', 'irregular', 'accounting', 'practice', 'telecom', 'giant', 'warning', 'collapse', 'discovery', 'accounting', 'fraud', 'ebbers', 'plead', 'guilty', 'fraud', 'conspiracy', 'prosecution', 'lawyer', 'argue', 'ebbers', 'orchestrate', 'accounting', 'trick', 'worldcom', 'ordering', 'employee', 'expense', 'inflate', 'revenue', 'earnings', 'estimate', 'cooper', 'consult', 'external', 'auditor', 'arthur', 'andersen', 'approve', 'worldcom', 'accounting', 'andersen', 'green', 'procedure', 'practice', 'worldcom', 'ebber', 'lawyer', 'unaware', 'fraud', 'arguing', 'auditor', 'alert', 'cooper', 'shareholder', 'meeting', 'ebbers', 'technical', 'finance', 'brief', 'answer', 'prosecution', 'witness', 'worldcom', 'scott', 'sullivan', 'ebbers', 'order', 'accounting', 'adjustment', 'telling', 'cooper', 'sullivan', 'mention', 'uncomfortable', 'worldcom', 'accounting', 'audit', 'ebbers', 'sentence', 'convict', 'worldcom', 'emerge', 'bankruptcy', 'protection', 'agree', 'buyout', 'verizon', 'communications', 'value', '675bn'], ['german', 'confidence', 'slide', 'german', 'confidence', 'knocking', 'speedy', 'recovery', 'munichbased', 'institute', 'confidence', 'index', 'decline', 'outlook', 'manufacturing', 'retail', 'sector', 'worsen', 'observer', 'confident', 'sector', 'signal', 'activity', 'picking', 'surprise', 'index', 'knock', 'economist', 'bernd', 'weidensteiner', 'domestic', 'retail', 'labour', 'wolfgang', 'clement', 'confidence', 'figure', 'decline', 'retreat', 'index', 'remain', 'relatively', 'modest', 'upswing', 'germany', 'shrinking', 'contract', 'mainly', 'reluctance', 'consumer', 'spend', 'indication', 'prove', 'elusive', 'hanswerner', 'improvement', 'german', 'domestic', 'sluggish', 'export', 'export', 'level', 'german', 'product', 'competitive', 'overseas', 'unemployment', 'stick', 'manufacturing', 'daimlerchrysler', 'siemens', 'volkswagen', 'negotiate', 'union', 'cutting', 'measure', 'analyst', 'figure', 'germany', 'continue', 'delay', 'eurozone', 'rates', 'focus', 'threat', 'inflation', 'prompting', 'rates']]
#
# LENGTH:
# 1490

# %% [markdown]
# **Discussion**
#
# The final list contains 1490 entries.

# %%
# turn tokens back into strings
# concatenate using whitespaces

clean_sentences = [" ".join(i) for i in clean]

# %%
print(clean_sentences[0:4])
# Out:
# ['worldcom exboss launch defence lawyer defend worldcom bernie ebbers battery fraud whistleblower witness cynthia cooper worldcom exhead internal accounting alert director irregular accounting practice telecom giant warning collapse discovery accounting fraud ebbers plead guilty fraud conspiracy prosecution lawyer argue ebbers orchestrate accounting trick worldcom ordering employee expense inflate revenue earnings estimate cooper consult external auditor arthur andersen approve worldcom accounting andersen green procedure practice worldcom ebber lawyer unaware fraud arguing auditor alert cooper shareholder meeting ebbers technical finance brief answer prosecution witness worldcom scott sullivan ebbers order accounting adjustment telling cooper sullivan mention uncomfortable worldcom accounting audit ebbers sentence convict worldcom emerge bankruptcy protection agree buyout verizon communications value 675bn', 'german confidence slide german confidence knocking speedy recovery munichbased institute confidence index decline outlook manufacturing retail sector worsen observer confident sector signal activity picking surprise index knock economist bernd weidensteiner domestic retail labour wolfgang clement confidence figure decline retreat index remain relatively modest upswing germany shrinking contract mainly reluctance consumer spend indication prove elusive hanswerner improvement german domestic sluggish export export level german product competitive overseas unemployment stick manufacturing daimlerchrysler siemens volkswagen negotiate union cutting measure analyst figure germany continue delay eurozone rates focus threat inflation prompting rates', 'indicate gloom citizen majority nation survey worsening respondent worse outlook majority positive question mostly conduct asian tsunami disaster majority plurality believe downhill compare respondent believe improve survey split percentage respondent worse compare improve similarly pessimistic optimistic conditions improve worse conduct globescan attitude maryland fully absorb personally experience effects steven perception terrorism religious division worse reflect elizabeth blunt optimistic family fastgrowing developing economy indonesia blistering wealth creation scale louisa beijing reflect untrammelled confidence subject endless propaganda correspondent korea pessimistic respondent italy mexico gloomy willey changeover widely wages salary philippines upbeat prospect respondent family pessimistic conduct facetoface telephone interview interview margin error depend sample metropolitan', 'lifestyle govern mobile choice funky hardware alone handset suggest customer pushing consumer interest handset lifestyle screen onboard memory indepth handset maker ericsson historically bjorn advisor mobile ericsson consumer enterprise technology speak consumer language ericsson interview mobile owner habit bjorn activity mobile convenient diarywriting younger diary mobile equip camera youngster message reflect desire contact slightly bjorn consumer sheer variety handset technology gradually habit lifestyle ericsson consumer divide tribe phone bjorn pioneer materialist interest trend instance older younger ageing mobile owner encourage older touch factor governing speed mobile speed devices pioneer materialist handset innovation camera consumer worrying picture innovation bjorn camera usage japan imply innovation japanese ericsson question camera figure similarly numbers camera phonecam figure nation bjorn camera phone camera usage pattern camera exactly replacing usage pattern analogue camera camera wedding holiday birthday contrast camera phone capture weave everyday']

# %% [markdown]
# # **Models:**
#
# Develop code to first vectorize your data, and then to train at least six LDA and NMF topic models on these vectors. Make clear section headings for each type of model, record each set of hyperparameters (for both vectorization and the topic models) you try, and find the perplexity, word-topic table and document-topic table for each; present this information neatly and use it to choose your best LDA and NMF models.

# %%
# import the appropriate packages depending on the environment
import pyLDAvis.sklearn  # plotting
# import pyLDAvis.lda_model  # plotting

# %% [markdown]
# ## LDA Model

# %%
# define function to calculate perplexity based on number of topics
def perplexity_by_ntopic(data, ntopics):
    output_dict = {
        "Number Of Topics": [],
        "Perplexity Score": []
    }

    for t in ntopics:
        lda = LatentDirichletAllocation(
            n_components=t,
            learning_method="online",
            random_state=0
        )
        lda.fit(data)

        output_dict["Number Of Topics"].append(t)
        output_dict["Perplexity Score"].append(lda.perplexity(data))

    output_df = pd.DataFrame(output_dict)

    index_min_perplexity = output_df["Perplexity Score"].idxmin()
    output_num_topics = output_df.loc[
        index_min_perplexity,  # index
        "Number Of Topics"  # column
    ]

    return (output_df, output_num_topics)

# %%
# define a function to do bag of words conversion
def do_bag_of_words_conversion(clean_sentences, max_df, min_df, max_features):
    # convert to bag of words
    vectorizer = CountVectorizer(
        analyzer="word",
        max_df=max_df,    # ignore words that appear in max_df% of documents
        min_df=min_df,    # ignore words that appear in less than min_df documents
        max_features=max_features
    )
    bow = vectorizer.fit_transform(clean_sentences)

    # use appropriate code depending on the environment
    feature_names_vec = vectorizer.get_feature_names()
    # feature_names_vec = vectorizer.get_feature_names_out()

    return vectorizer, bow, feature_names_vec

# %%
# define a function to do bag of words conversion and obtain the perplexity
def get_perplexity_and_plot(bow, max_ntopics):

    # execute function on vector of numbers of topics
    perplexity, optimal_num_topics = perplexity_by_ntopic(
        bow,
        ntopics=list(range(1, max_ntopics+1))
    )

    print(perplexity)
    print('\n')
    print(f'Optimal Number of Topics: {optimal_num_topics}')

    # plot perplexity by number of topics
    # plt.figure(figsize=(6, 3))
    plt.figure(figsize=(3, 2))
    plt.plot(perplexity["Number Of Topics"], perplexity["Perplexity Score"])
    plt.xlabel("Number Of Topics")
    plt.ylabel("Perplexity Score")
    plt.title("Perplexity Score By Number Of Topics")
    plt.show()

    return perplexity, optimal_num_topics

# %%
# define a function to do LDA
def do_lda(bow, num_topics):
    # fit and transform the data
    lda = LatentDirichletAllocation(
        n_components=num_topics,  # optimal_num_topics,
        learning_method="online",
        random_state=0
    )
    lda.fit(bow)

    lda_transform = lda.transform(bow)

    # obtain the components
    lda_components = lda.components_

    return lda, lda_transform, lda_components

# %%
# define function to format raw output into nice tables

def get_topics(mod, vec, names, docs, ndocs, nwords):
    # word to topic matrix
    W = mod.components_
    W_norm = W / W.sum(axis=1)[:, np.newaxis]
    # topic to document matrix
    H = mod.transform(vec)

    W_dict = {}
    H_dict = {}

    for tpc_idx, tpc_val in enumerate(W_norm):
        topic = "Topic{}".format(tpc_idx)

        # formatting w
        W_indices = tpc_val.argsort()[::-1][:nwords]
        W_names_values = [
            (round(tpc_val[j], 4), names[j])
            for j in W_indices
        ]
        W_dict[topic] = W_names_values

        # formatting h
        H_indices = H[:, tpc_idx].argsort()[::-1][:ndocs]
        H_names_values = [
            (round(H[:, tpc_idx][j], 4), docs[j])
            for j in H_indices
        ]
        H_dict[topic] = H_names_values

    W_df = pd.DataFrame(
        W_dict,
        index=["Word" + str(i) for i in range(nwords)]
    )
    H_df = pd.DataFrame(
        H_dict,
        index=["Doc" + str(i) for i in range(ndocs)]
    )

    return (W_df, H_df)

# %%
# define functiont to fit and plot t-SNE model

def plot_tsne(data, threshold):
    # filter data according to threshold
    index_meet_threshold = np.amax(data, axis=1) >= threshold
    lda_transform_filt = data[index_meet_threshold]

    # fit tsne model
    # x-d -> 2-d, x = number of topics
    tsne = TSNE(
        n_components=2,
        verbose=0,
        random_state=0,
        angle=0.5,
        init='pca'
    )
    tsne_fit = tsne.fit_transform(lda_transform_filt)

    # most probable topic for each headline
    most_prob_topic = []
    for i in range(tsne_fit.shape[0]):
        most_prob_topic.append(lda_transform_filt[i].argmax())

    # print("LENGTH:\n{}\n".format(len(most_prob_topic)))

    unique, counts = np.unique(
        np.array(most_prob_topic),
        return_counts=True
    )

    # print("COUNTS:\n{}\n".format(np.asarray((unique, counts)).T))

    # make plot
    color_list = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'orange', 'purple']

    for i in list(set(most_prob_topic)):
        indices = [idx for idx, val in enumerate(most_prob_topic) if val == i]
        plt.scatter(
            x=tsne_fit[indices, 0],
            y=tsne_fit[indices, 1],
            s=1,
            c=color_list[i],
            label='Topic' + str(i),
            alpha=0.5
        )

    plt.xlabel('x-tsne')
    plt.ylabel('y-tsne')
    plt.legend(markerscale=10, bbox_to_anchor=(1.04, 1), loc="upper left")

# %%
# define global variables for visualization of LDA results
number_words = 10
number_docs = 10

# %%
# setup a dictionary to setup parameters and store the results
lda_dict = {}

# %% [markdown]
# ### LDA Model 1 {'number_features': 1500, 'vec_max_df': 0.05, 'vec_min_df': 20}

# %%
mod_name = 'lda1'

# add parameters to dictionary
lda_dict[mod_name] = {
    'number_features': 1500,
    'vec_max_df': 0.05,
    'vec_min_df': 20
}

# %%
# perform bag of words conversion
vectorizer1, clean_vec1, feature_names_vec1 = do_bag_of_words_conversion(
    clean_sentences,
    lda_dict[mod_name]['vec_max_df'],
    lda_dict[mod_name]['vec_min_df'],
    lda_dict[mod_name]['number_features']
    )

# get perplexity and plot
perplexity1, optimal_num_topics1 = get_perplexity_and_plot(clean_vec1, 8)
# Out:
#    Number Of Topics  Perplexity Score
# 0                 1       1044.984562
# 1                 2        912.966717
# 2                 3        856.094455
# 3                 4        852.896590
# 4                 5        813.227926
# 5                 6        780.587092
# 6                 7        755.739861
# 7                 8        782.380783
#
#
# Optimal Number of Topics: 7

# %%
# run the do_lda function
lda1, lda_transform1, lda_components1 = do_lda(
    clean_vec1,
    optimal_num_topics1
    )

# get nice tables
W_df1, H_df1 = get_topics(
    mod=lda1,
    vec=clean_vec1,
    names=feature_names_vec1,
    docs=raw,
    ndocs=number_docs,
    nwords=number_words
    )

# %%
# word-topic table: top 10 words for each topic
W_df1
# Out:
#                      Topic0               Topic1                  Topic2  \
# Word0       (0.0217, oscar)     (0.0442, search)       (0.0156, chelsea)
# Word1       (0.02, actress)      (0.0344, chart)         (0.0113, rugby)
# Word2       (0.0194, prize)      (0.0287, album)      (0.0108, williams)
# Word3      (0.0164, singer)   (0.0236, festival)       (0.0104, arsenal)
# Word4  (0.0162, production)     (0.0193, studio)       (0.0097, olympic)
# Word5  (0.0154, nomination)     (0.0171, google)  (0.0096, championship)
# Word6    (0.0149, producer)  (0.0153, christmas)         (0.0094, irish)
# Word7     (0.014, ceremony)     (0.0153, record)    (0.0093, manchester)
# Word8    (0.0137, audience)      (0.0151, speed)     (0.0092, liverpool)
# Word9     (0.013, category)  (0.0124, broadband)         (0.0092, davis)
#
#                     Topic3                 Topic4               Topic5  \
# Word0    (0.0101, airline)        (0.0117, fraud)  (0.0198, microsoft)
# Word1    (0.0093, kennedy)  (0.0115, shareholder)     (0.0186, gadget)
# Word2      (0.0091, trust)     (0.0113, criminal)      (0.0164, virus)
# Word3     (0.0089, reform)       (0.0097, asylum)    (0.0156, machine)
# Word4      (0.0087, voter)   (0.0088, bankruptcy)      (0.0128, apple)
# Word5    (0.0075, commons)       (0.0087, lawyer)  (0.0128, broadband)
# Word6  (0.0072, education)   (0.0079, parliament)   (0.0124, download)
# Word7    (0.0072, pension)      (0.0079, russian)    (0.0119, network)
# Word8     (0.0071, debate)      (0.0078, suspect)    (0.0113, devices)
# Word9     (0.0069, pledge)     (0.0076, document)     (0.0098, gaming)
#
#                    Topic6
# Word0     (0.0171, rates)
# Word1     (0.0152, japan)
# Word2     (0.0151, phone)
# Word3   (0.0145, profits)
# Word4   (0.0142, deficit)
# Word5    (0.0132, export)
# Word6    (0.0117, camera)
# Word7    (0.0109, market)
# Word8  (0.0108, forecast)
# Word9   (0.0104, germany)

# %%
# document-topic table: top 10 documents for each topic
H_df1
# Out:
#                                                  Topic0  \
# Doc0  (0.9847, bafta to hand out movie honours movie...
# Doc1  (0.9813, levy tipped for whitbread prize novel...
# Doc2  (0.9813, bbc leads interactive bafta wins the ...
# Doc3  (0.9801, stars gear up for bafta ceremony film...
# Doc4  (0.9761, oscar host rock to keep it clean osca...
# Doc5  (0.974, south bank awards honour hit soap coro...
# Doc6  (0.9723, queen recruit singer for new tour the...
# Doc7  (0.9723, queen recruit singer for new tour the...
# Doc8  (0.9714, us critics laud comedy sideways road ...
# Doc9  (0.9701, levy takes whitbread novel prize oran...
#
#                                                  Topic1  \
# Doc0  (0.9852, downloads enter us singles chart digi...
# Doc1  (0.9852, downloads enter us singles chart digi...
# Doc2  (0.974, prodigy join v festival line-up essex ...
# Doc3  (0.9704, fockers fuel festive film chart comed...
# Doc4  (0.9643, brits return keane to number one brit...
# Doc5  (0.9627, streets have  album of the year  the ...
# Doc6  (0.9522, hillbillies singer scoggins dies coun...
# Doc7  (0.9495, pop band busted to  take a break  cha...
# Doc8  (0.9495, pop band busted to  take a break  cha...
# Doc9  (0.9463, fockers keeps us box office lead film...
#
#                                                  Topic2  \
# Doc0  (0.9911, wales win in rome wales secured their...
# Doc1  (0.9905, nadal puts spain 2-0 up result: nadal...
# Doc2  (0.9903, britain boosted by holmes double athl...
# Doc3  (0.9888, paris promise raises welsh hopes has ...
# Doc4  (0.9868, chelsea hold arsenal a gripping game ...
# Doc5  (0.9854, ireland surge past scots ireland main...
# Doc6  (0.9854, campbell rescues arsenal sol campbell...
# Doc7  (0.9847, o driscoll saves irish blushes two mo...
# Doc8  (0.9832, jones happy with henson heroics wales...
# Doc9  (0.9832, white prepared for battle tough-scrum...
#
#                                                  Topic3  \
# Doc0  (0.99, goldsmith denies war advice claim the a...
# Doc1  (0.9888, goldsmith:  i was not leant on  the a...
# Doc2  (0.9838, debate needed  on donations cap a cap...
# Doc3  (0.9838, debate needed  on donations cap a cap...
# Doc4  (0.9835, blair rejects iraq advice calls tony ...
# Doc5  (0.9805, talks aim to avert pension strike tal...
# Doc6  (0.9805, talks aim to avert pension strike tal...
# Doc7  (0.98, stalemate in pension strike talks talks...
# Doc8  (0.978, civil servants in strike ballot the uk...
# Doc9  (0.9747, brown outlines third term vision gord...
#
#                                                  Topic4  \
# Doc0  (0.9894, dozens held over id fraud site twenty...
# Doc1  (0.9864, enron bosses in $168m payout eighteen...
# Doc2  (0.9841, worldcom director admits lying the fo...
# Doc3  (0.9835, worldcom ex-boss launches defence law...
# Doc4  (0.9832, ebbers denies worldcom fraud former w...
# Doc5  (0.98, borders rail link campaign rally campai...
# Doc6  (0.9796, worldcom bosses  $54m payout ten form...
# Doc7  (0.9774, id theft surge hits us consumers almo...
# Doc8  (0.9643, insurance bosses plead guilty another...
# Doc9  (0.961, parmalat bank barred from suing bank o...
#
#                                                  Topic5  \
# Doc0  (0.9941, apple laptop is  greatest gadget  the...
# Doc1  (0.9928, apple laptop is  greatest gadget  the...
# Doc2  (0.9927, rivals of the £400 apple... the mac m...
# Doc3  (0.9901, doors open at biggest gadget fair tho...
# Doc4  (0.9901, doors open at biggest gadget fair tho...
# Doc5  (0.9881, gates opens biggest gadget fair bill ...
# Doc6  (0.9862, microsoft makes anti-piracy move micr...
# Doc7  (0.9841, virus poses as christmas e-mail secur...
# Doc8  (0.9841, virus poses as christmas e-mail secur...
# Doc9  (0.9838, microsoft debuts security tools micro...
#
#                                                  Topic6
# Doc0  (0.989, camera phones are  must-haves  four ti...
# Doc1  (0.989, camera phones are  must-haves  four ti...
# Doc2  (0.9881, uk interest rates held at 4.75% the b...
# Doc3  (0.9838, german business confidence slides ger...
# Doc4  (0.9832, bank opts to leave rates on hold the ...
# Doc5  (0.9817, optimism remains over uk housing the ...
# Doc6  (0.9805, brewers  profits lose their fizz hein...
# Doc7  (0.98, trade gap narrows as exports rise the u...
# Doc8  (0.9791, golden economic period  to end ten ye...
# Doc9  (0.9785, uk  risks breaking golden rule  the u...

# %%
# get perplexity for optimal number of topics
perplexity1 = perplexity1.loc[perplexity1['Number Of Topics'] == optimal_num_topics1, 'Perplexity Score'].values[0]
lda_dict[mod_name]['perplexity'] = perplexity1

# put the results into a dictionary
lda_dict[mod_name]['optimal_num_topics'] = optimal_num_topics1
lda_dict[mod_name]['W_df'] = W_df1
lda_dict[mod_name]['H_df'] = H_df1

# %% [markdown]
# ### LDA Model 2 {'number_features': 1750, 'vec_max_df': 0.05, 'vec_min_df': 12}

# %%
mod_name = 'lda2'

# add parameters to dictionary
lda_dict[mod_name] = {
    'number_features': 1750,
    'vec_max_df': 0.05,
    'vec_min_df': 12
}

# %%
# perform bag of words conversion
vectorizer2, clean_vec2, feature_names_vec2 = do_bag_of_words_conversion(
    clean_sentences,
    lda_dict[mod_name]['vec_max_df'],
    lda_dict[mod_name]['vec_min_df'],
    lda_dict[mod_name]['number_features']
    )

# get perplexity and plot
perplexity2, optimal_num_topics2 = get_perplexity_and_plot(clean_vec2, 6)
# Out:
#    Number Of Topics  Perplexity Score
# 0                 1       1567.072770
# 1                 2       1365.755911
# 2                 3       1199.100750
# 3                 4       1141.680584
# 4                 5       1178.806321
# 5                 6       1176.848048
#
#
# Optimal Number of Topics: 4

# %%
# run the do_lda function
lda2, lda_transform2, lda_components2 = do_lda(
    clean_vec2,
    optimal_num_topics2
    )

# get nice tables
W_df2, H_df2 = get_topics(
    mod=lda2,
    vec=clean_vec2,
    names=feature_names_vec2,
    docs=raw,
    ndocs=number_docs,
    nwords=number_words
    )

# %%
# word topic table: top 10 words for each topic
W_df2
# Out:
#                      Topic0                  Topic1               Topic2  \
# Word0       (0.0047, rates)       (0.0109, chelsea)  (0.0134, microsoft)
# Word1  (0.0044, parliament)         (0.0079, rugby)     (0.0127, search)
# Word2       (0.0039, stock)      (0.0075, williams)  (0.0118, broadband)
# Word3     (0.0037, deficit)       (0.0073, arsenal)     (0.0118, gadget)
# Word4    (0.0037, exchange)    (0.0069, manchester)      (0.0108, virus)
# Word5     (0.0037, kennedy)       (0.0068, olympic)    (0.0096, machine)
# Word6      (0.0036, reform)  (0.0068, championship)      (0.0082, apple)
# Word7      (0.0035, export)         (0.0065, irish)     (0.008, network)
# Word8      (0.0034, debate)     (0.0065, liverpool)      (0.0078, phone)
# Word9       (0.0034, trust)         (0.0063, jones)    (0.0074, airline)
#
#                    Topic3
# Word0      (0.011, chart)
# Word1     (0.0105, oscar)
# Word2     (0.0103, album)
# Word3   (0.0089, actress)
# Word4    (0.0086, singer)
# Word5     (0.0083, yukos)
# Word6  (0.0082, festival)
# Word7      (0.008, prize)
# Word8  (0.0078, producer)
# Word9  (0.0072, audience)

# %%
# document topic table: top 10 documents for each topic
H_df2
# Out:
#                                                  Topic0  \
# Doc0  (0.9975, minimum wage increased to £5.05 the m...
# Doc1  (0.9937, booming markets shed few tears the ma...
# Doc2  (0.9935, giant waves damage s asia economy gov...
# Doc3  (0.9919, anti-terror plan faces first test pla...
# Doc4  (0.9915, asia quake increases poverty risk nea...
# Doc5  (0.9912, howard unveils tory asylum plans tory...
# Doc6  (0.9912, india unveils anti-poverty budget ind...
# Doc7  (0.991, muslims discuss election concerns issu...
# Doc8  (0.9908, goldsmith:  i was not leant on  the a...
# Doc9  (0.9907, brown targets oaps and homebuyers gor...
#
#                                                  Topic1  \
# Doc0  (0.996, all black magic: new zealand rugby pla...
# Doc1  (0.9957, nadal puts spain 2-0 up result: nadal...
# Doc2  (0.9936, britain boosted by holmes double athl...
# Doc3  (0.9931, what now for kelly holmes  last april...
# Doc4  (0.9931, wales win in rome wales secured their...
# Doc5  (0.9926, henman to face saulnier test british ...
# Doc6  (0.9923, a year to remember for irish there us...
# Doc7  (0.9922, holmes back on form in birmingham dou...
# Doc8  (0.992, chelsea hold arsenal a gripping game b...
# Doc9  (0.992, ireland 17-12 south africa ronan o gar...
#
#                                                  Topic2  \
# Doc0  (0.995, apple laptop is  greatest gadget  the ...
# Doc1  (0.9933, toxic web links help virus spread vir...
# Doc2  (0.9926, concerns over windows atms cash machi...
# Doc3  (0.9913, apple mac mini gets warm welcome the ...
# Doc4  (0.9909, have hackers recruited your pc  more ...
# Doc5  (0.9902, security scares spark browser fix mic...
# Doc6  (0.9889, google s toolbar sparks concern searc...
# Doc7  (0.9887, rivals of the £400 apple... the mac m...
# Doc8  (0.9884, virus poses as christmas e-mail secur...
# Doc9  (0.9884, virus poses as christmas e-mail secur...
#
#                                                  Topic3
# Doc0  (0.9961, critics back aviator for oscars marti...
# Doc1  (0.9933, the producers scoops stage awards the...
# Doc2  (0.993, aviator wins top globes accolades the ...
# Doc3  (0.9923, eastwood s baby scoops top oscars cli...
# Doc4  (0.9916, british stars denied major oscars bri...
# Doc5  (0.9908, stars shine on bafta red carpet holly...
# Doc6  (0.9905, bafta to hand out movie honours movie...
# Doc7  (0.9902, vera drake s bafta triumph hope at th...
# Doc8  (0.9901, hollywood ready for oscars night holl...
# Doc9  (0.99, grammys honour soul star charles the me...

# %%
# get perplexity for optimal number of topics
perplexity2 = perplexity2.loc[perplexity2['Number Of Topics'] == optimal_num_topics2, 'Perplexity Score'].values[0]
lda_dict[mod_name]['perplexity'] = perplexity2

# put the results into a dictionary
lda_dict[mod_name]['optimal_num_topics'] = optimal_num_topics2
lda_dict[mod_name]['W_df'] = W_df2
lda_dict[mod_name]['H_df'] = H_df2

# %% [markdown]
# ### LDA Model 3 {'number_features': 1500, 'vec_max_df': 0.02, 'vec_min_df': 15}

# %%
mod_name = 'lda3'

# add parameters to dictionary
lda_dict[mod_name] = {
    'number_features': 1500,
    'vec_max_df': 0.02,
    'vec_min_df': 15
}

# %%
# perform bag of words conversion
vectorizer3, clean_vec3, feature_names_vec3 = do_bag_of_words_conversion(
    clean_sentences,
    lda_dict[mod_name]['vec_max_df'],
    lda_dict[mod_name]['vec_min_df'],
    lda_dict[mod_name]['number_features']
    )

# get perplexity and plot
perplexity3, optimal_num_topics3 = get_perplexity_and_plot(clean_vec3, 5)
# Out:
#    Number Of Topics  Perplexity Score
# 0                 1        942.924946
# 1                 2        859.591107
# 2                 3        854.003968
# 3                 4        878.386161
# 4                 5        879.469404
#
#
# Optimal Number of Topics: 3

# %%
# run the do_lda function
lda3, lda_transform3, lda_components3 = do_lda(
    clean_vec3,
    optimal_num_topics3
    )

# get nice tables
W_df3, H_df3 = get_topics(
    mod=lda3,
    vec=clean_vec3,
    names=feature_names_vec3,
    docs=raw,
    ndocs=number_docs,
    nwords=number_words
    )

# %%
# word topic table: top 10 words for each topic
W_df3
# Out:
#                    Topic0               Topic1              Topic2
# Word0     (0.0138, yukos)   (0.0086, campbell)    (0.0067, clarke)
# Word1   (0.0129, airline)    (0.007, ferguson)   (0.0061, poverty)
# Word2    (0.0127, google)      (0.007, athens)  (0.0059, mourinho)
# Word3   (0.0103, roddick)       (0.006, medal)    (0.0059, arrest)
# Word4    (0.0093, asylum)       (0.006, dance)    (0.0059, poster)
# Word5   (0.0087, handset)    (0.006, musician)    (0.0059, terror)
# Word6  (0.0078, deutsche)     (0.0059, indoor)  (0.0057, blunkett)
# Word7    (0.0075, engine)  (0.0056, athletics)   (0.0051, housing)
# Word8  (0.0065, nintendo)     (0.0056, prince)      (0.005, index)
# Word9   (0.0065, auction)     (0.0055, laptop)  (0.0048, mortgage)

# %%
# document topic table: top 10 documents for each topic
H_df3
# Out:
#                                                  Topic0  \
# Doc0  (0.9923, nadal puts spain 2-0 up result: nadal...
# Doc1  (0.9851, yukos unit fetches $9bn at auction a ...
# Doc2  (0.9851, henman to face saulnier test british ...
# Doc3  (0.9846, toxic web links help virus spread vir...
# Doc4  (0.9826, rich pickings for hi-tech thieves vir...
# Doc5  (0.9818, microsoft makes anti-piracy move micr...
# Doc6  (0.9802, deutsche attacks yukos case german in...
# Doc7  (0.9799, nintendo ds aims to touch gamers the ...
# Doc8  (0.9794, warnings about junk mail deluge the a...
# Doc9  (0.9794, yukos seeks court action on sale yuko...
#
#                                                  Topic1  \
# Doc0  (0.9911, critics back aviator for oscars marti...
# Doc1  (0.9852, the producers scoops stage awards the...
# Doc2  (0.9846, britain boosted by holmes double athl...
# Doc3  (0.9843, goldsmith denies war advice claim the...
# Doc4  (0.9833, irish finish with home game republic ...
# Doc5  (0.9818, a year to remember for irish there us...
# Doc6  (0.9817, eastwood s baby scoops top oscars cli...
# Doc7  (0.9813, ireland 19-13 england ireland consign...
# Doc8  (0.981, aviator and vera take bafta glory holl...
# Doc9  (0.9807, vera drake leads uk oscar hopes mike ...
#
#                                                  Topic2
# Doc0  (0.9874, muslims discuss election concerns iss...
# Doc1  (0.982, terror suspects face house arrest uk c...
# Doc2  (0.98, anti-terror plan faces first test plans...
# Doc3  (0.9798, opposition grows to house arrests the...
# Doc4  (0.9793, intel unveils laser breakthrough inte...
# Doc5  (0.9783, blunkett unveils policing plans peopl...
# Doc6  (0.9779, text messages aid disaster recovery t...
# Doc7  (0.9762, boateng to step down at election paul...
# Doc8  (0.9758, anglers  could face prosecution  angl...
# Doc9  (0.9755, chancellor rallies labour voters gord...

# %%
# get perplexity for optimal number of topics
perplexity3 = perplexity3.loc[perplexity3['Number Of Topics'] == optimal_num_topics3, 'Perplexity Score'].values[0]
lda_dict[mod_name]['perplexity'] = perplexity3

# put the results into a dictionary
lda_dict[mod_name]['optimal_num_topics'] = optimal_num_topics3
lda_dict[mod_name]['W_df'] = W_df3
lda_dict[mod_name]['H_df'] = H_df3

# %% [markdown]
# ### LDA Model 4 {'number_features': 1250, 'vec_max_df': 0.1, 'vec_min_df': 15}

# %%
mod_name = 'lda4'

# add parameters to dictionary
lda_dict[mod_name] = {
    'number_features': 1250,
    'vec_max_df': 0.1,
    'vec_min_df': 15
}

# %%
# perform bag of words conversion
vectorizer4, clean_vec4, feature_names_vec4 = do_bag_of_words_conversion(
    clean_sentences,
    lda_dict[mod_name]['vec_max_df'],
    lda_dict[mod_name]['vec_min_df'],
    lda_dict[mod_name]['number_features']
    )

# get perplexity and plot
perplexity4, optimal_num_topics4 = get_perplexity_and_plot(clean_vec4, 7)
# Out:
#    Number Of Topics  Perplexity Score
# 0                 1       1081.353716
# 1                 2        918.644419
# 2                 3        872.918651
# 3                 4        799.835000
# 4                 5        723.033951
# 5                 6        726.676562
# 6                 7        745.330598
#
#
# Optimal Number of Topics: 5

# %%
# run the do_lda function
lda4, lda_transform4, lda_components4 = do_lda(
    clean_vec4,
    optimal_num_topics4
    )

# get nice tables
W_df4, H_df4 = get_topics(
    mod=lda4,
    vec=clean_vec4,
    names=feature_names_vec4,
    docs=raw,
    ndocs=number_docs,
    nwords=number_words
    )

# %%
# word topic table: top 10 words for each topic
W_df4
# Out:
#                       Topic0               Topic1              Topic2  \
# Word0        (0.0224, blair)     (0.0115, search)      (0.034, award)
# Word1         (0.017, brown)      (0.0111, share)     (0.0182, actor)
# Word2       (0.0124, howard)     (0.0093, dollar)     (0.0131, chart)
# Word3   (0.0094, chancellor)      (0.0092, virus)     (0.0125, oscar)
# Word4  (0.009, conservative)   (0.0082, software)     (0.0111, album)
# Word5      (0.0067, liberal)  (0.0073, microsoft)   (0.0106, actress)
# Word6   (0.0066, parliament)       (0.007, rates)     (0.0099, movie)
# Word7     (0.0066, democrat)      (0.0069, costs)  (0.0098, festival)
# Word8     (0.0059, minister)      (0.0066, stock)     (0.0093, prize)
# Word9      (0.0055, kennedy)   (0.0064, consumer)  (0.0087, producer)
#
#                     Topic3              Topic4
# Word0     (0.0344, mobile)   (0.0139, ireland)
# Word1   (0.0146, computer)    (0.0135, france)
# Word2  (0.0136, broadband)  (0.0128, champion)
# Word3     (0.0135, gadget)     (0.0128, wales)
# Word4   (0.0135, consumer)    (0.0112, injury)
# Word5      (0.0134, phone)     (0.0111, coach)
# Word6   (0.0119, download)    (0.011, chelsea)
# Word7     (0.01, software)     (0.0103, sport)
# Word8       (0.01, camera)     (0.0083, title)
# Word9      (0.0093, apple)      (0.008, rugby)

# %%
# document topic table: top 10 documents for each topic
H_df4
# Out:
#                                                  Topic0  \
# Doc0  (0.9928, anti-terror plan faces first test pla...
# Doc1  (0.9919, howard unveils tory asylum plans tory...
# Doc2  (0.9919, terror suspects face house arrest uk ...
# Doc3  (0.9911, howard denies split over id cards mic...
# Doc4  (0.9911, howard denies split over id cards mic...
# Doc5  (0.9909, howard taunts blair over splits tony ...
# Doc6  (0.9908, asylum children to face returns the u...
# Doc7  (0.9907, no more concessions  on terror charle...
# Doc8  (0.9906, blair defends terror law changes the ...
# Doc9  (0.99, voters  don t trust politicians  eight ...
#
#                                                  Topic1  \
# Doc0  (0.9911, security scares spark browser fix mic...
# Doc1  (0.9897, microsoft debuts security tools micro...
# Doc2  (0.9888, car giant hit by mercedes slump a slu...
# Doc3  (0.9884, asian banks halt dollar s slide the d...
# Doc4  (0.988, us trade deficit widens sharply the ga...
# Doc5  (0.9875, french suitor holds lse meeting europ...
# Doc6  (0.9873, domain system scam fear a system to m...
# Doc7  (0.9871, domain system opens door to scams a s...
# Doc8  (0.987, microsoft sets sights on spyware windo...
# Doc9  (0.9869, asia shares defy post-quake gloom ind...
#
#                                                  Topic2  \
# Doc0  (0.9965, critics back aviator for oscars marti...
# Doc1  (0.9924, eastwood s baby scoops top oscars cli...
# Doc2  (0.9916, aviator and vera take bafta glory hol...
# Doc3  (0.9912, british stars denied major oscars bri...
# Doc4  (0.9898, bafta to hand out movie honours movie...
# Doc5  (0.989, new york rockers top talent poll new y...
# Doc6  (0.989, stars shine on bafta red carpet hollyw...
# Doc7  (0.9888, foxx and swank take actors awards jam...
# Doc8  (0.9886, foxx and swank win us awards jamie fo...
# Doc9  (0.9884, new york rockers top talent poll new ...
#
#                                                  Topic3  \
# Doc0  (0.9959, apple laptop is  greatest gadget  the...
# Doc1  (0.995, apple laptop is  greatest gadget  the ...
# Doc2  (0.9934, broadband set to revolutionise tv bt ...
# Doc3  (0.9934, tv s future down the phone line inter...
# Doc4  (0.993, mobiles  not media players yet  mobile...
# Doc5  (0.993, mobiles  not media players yet  mobile...
# Doc6  (0.9929, nintendo ds aims to touch gamers the ...
# Doc7  (0.9929, mobile music challenges  ipod age  no...
# Doc8  (0.9928, doors open at biggest gadget fair tho...
# Doc9  (0.9928, doors open at biggest gadget fair tho...
#
#                                                  Topic4
# Doc0  (0.9952, nadal puts spain 2-0 up result: nadal...
# Doc1  (0.9934, britain boosted by holmes double athl...
# Doc2  (0.9926, wales win in rome wales secured their...
# Doc3  (0.9924, celts savour grand slam prospect the ...
# Doc4  (0.9922, holmes back on form in birmingham dou...
# Doc5  (0.9921, a november to remember last saturday ...
# Doc6  (0.992, mourinho plots impressive course chels...
# Doc7  (0.9919, ireland 17-12 south africa ronan o ga...
# Doc8  (0.9914, ireland 19-13 england ireland consign...
# Doc9  (0.9909, henman to face saulnier test british ...

# %%
# get perplexity for optimal number of topics
perplexity4 = perplexity4.loc[perplexity4['Number Of Topics'] == optimal_num_topics4, 'Perplexity Score'].values[0]
lda_dict[mod_name]['perplexity'] = perplexity4

# put the results into a dictionary
lda_dict[mod_name]['optimal_num_topics'] = optimal_num_topics4
lda_dict[mod_name]['W_df'] = W_df4
lda_dict[mod_name]['H_df'] = H_df4

# %% [markdown]
# ### LDA Model 5 {'number_features': 1250, 'vec_max_df': 0.1, 'vec_min_df': 7}

# %%
mod_name = 'lda5'

# add parameters to dictionary
lda_dict[mod_name] = {
    'number_features': 1250,
    'vec_max_df': 0.1,
    'vec_min_df': 7
}

# %%
# perform bag of words conversion
vectorizer5, clean_vec5, feature_names_vec5 = do_bag_of_words_conversion(
    clean_sentences,
    lda_dict[mod_name]['vec_max_df'],
    lda_dict[mod_name]['vec_min_df'],
    lda_dict[mod_name]['number_features']
    )

# get perplexity and plot
perplexity5, optimal_num_topics5 = get_perplexity_and_plot(clean_vec5, 8)
# Out:
#    Number Of Topics  Perplexity Score
# 0                 1       1090.033052
# 1                 2        944.608392
# 2                 3        860.643149
# 3                 4        782.771207
# 4                 5        745.968339
# 5                 6        700.945668
# 6                 7        730.709280
# 7                 8        732.874544
#
#
# Optimal Number of Topics: 6

# %%
# run the do_lda function
lda5, lda_transform5, lda_components5 = do_lda(
    clean_vec5,
    optimal_num_topics5
    )

# get nice tables
W_df5, H_df5 = get_topics(
    mod=lda5,
    vec=clean_vec5,
    names=feature_names_vec5,
    docs=raw,
    ndocs=number_docs,
    nwords=number_words
    )

# %%
# word topic table: top 10 words for each topic
W_df5
# Out:
#                    Topic0              Topic1                  Topic2  \
# Word0     (0.0106, trial)    (0.0167, france)         (0.0268, blair)
# Word1     (0.0105, irish)      (0.015, wales)         (0.0228, brown)
# Word2     (0.0094, fraud)  (0.0147, champion)         (0.016, howard)
# Word3  (0.0091, scotland)    (0.0127, injury)     (0.012, chancellor)
# Word4   (0.0091, ireland)   (0.0126, chelsea)  (0.0109, conservative)
# Word5   (0.0077, suspect)     (0.0126, coach)       (0.0074, liberal)
# Word6    (0.0072, lawyer)     (0.0118, sport)      (0.0074, democrat)
# Word7     (0.0072, power)   (0.0104, ireland)       (0.0073, kennedy)
# Word8  (0.0069, scottish)     (0.0092, title)      (0.0069, spending)
# Word9     (0.0068, order)     (0.0086, rugby)       (0.0067, promise)
#
#                   Topic3               Topic4              Topic5
# Word0   (0.0311, mobile)   (0.0172, software)     (0.0369, award)
# Word1    (0.0147, share)   (0.0169, computer)     (0.0192, actor)
# Word2    (0.0137, phone)   (0.0129, internet)     (0.0132, oscar)
# Word3   (0.0132, dollar)   (0.0127, consumer)     (0.0128, album)
# Word4    (0.0093, stock)     (0.0125, search)     (0.0124, chart)
# Word5  (0.0093, profits)  (0.0125, microsoft)     (0.0112, movie)
# Word6   (0.009, airline)   (0.0111, download)   (0.0112, actress)
# Word7    (0.0088, costs)   (0.011, broadband)    (0.0107, singer)
# Word8  (0.0086, deficit)     (0.0099, gadget)     (0.0105, prize)
# Word9    (0.0085, rates)      (0.0097, virus)  (0.0103, festival)

# %%
# document topic table: top 10 documents for each topic
H_df5
# Out:
#                                                  Topic0  \
# Doc0  (0.99, worldcom director admits lying the form...
# Doc1  (0.9887, worldcom director ends evidence the f...
# Doc2  (0.9884, worldcom ex-boss launches defence law...
# Doc3  (0.9873, ebbers denies worldcom fraud former w...
# Doc4  (0.9869, woolf murder sentence rethink plans t...
# Doc5  (0.9858, no-one can define new hunt ban  the n...
# Doc6  (0.9832, guantanamo man  suing government  a b...
# Doc7  (0.9829, ministers  naive  over phone-taps the...
# Doc8  (0.9825, borders rail link campaign rally camp...
# Doc9  (0.9721, jp morgan admits us slavery links tho...
#
#                                                  Topic1  \
# Doc0  (0.9961, nadal puts spain 2-0 up result: nadal...
# Doc1  (0.9942, britain boosted by holmes double athl...
# Doc2  (0.9918, holmes back on form in birmingham dou...
# Doc3  (0.9916, henman to face saulnier test british ...
# Doc4  (0.9911, federer joins all-time greats the las...
# Doc5  (0.9878, giggs handed wales leading role ryan ...
# Doc6  (0.9877, white prepared for battle tough-scrum...
# Doc7  (0.9867, sella wants michalak recall former fr...
# Doc8  (0.9853, france v wales (sat) stade de france ...
# Doc9  (0.9845, campbell to extend sprint career darr...
#
#                                                  Topic2  \
# Doc0  (0.9907, howard denies split over id cards mic...
# Doc1  (0.9907, howard denies split over id cards mic...
# Doc2  (0.9895, tories attack eu asylum moves david b...
# Doc3  (0.989, blair ready to call election tony blai...
# Doc4  (0.9887, brown calls for £5.5bn aids fund gord...
# Doc5  (0.9887, taxes must be trusted - kennedy publi...
# Doc6  (0.9885, debate needed  on donations cap a cap...
# Doc7  (0.9885, debate needed  on donations cap a cap...
# Doc8  (0.9885, budget to set scene for election gord...
# Doc9  (0.9875, will tory tax cuts lift spirits  mich...
#
#                                                  Topic3  \
# Doc0  (0.9887, asian banks halt dollar s slide the d...
# Doc1  (0.9886, ore costs hit global steel firms shar...
# Doc2  (0.9886, car giant hit by mercedes slump a slu...
# Doc3  (0.9875, us trade deficit widens sharply the g...
# Doc4  (0.9871, bmw cash to fuel mini production less...
# Doc5  (0.9836, brewers  profits lose their fizz hein...
# Doc6  (0.9835, mobiles rack up 20 years of use mobil...
# Doc7  (0.9835, mobiles rack up 20 years of use mobil...
# Doc8  (0.9825, gm issues 2005 profits warning genera...
# Doc9  (0.9814, us trade gap ballooned in october the...
#
#                                                  Topic4  \
# Doc0  (0.9927, format wars could  confuse users  tec...
# Doc1  (0.9927, format wars could  confuse users  tec...
# Doc2  (0.9926, search wars hit desktop pcs another f...
# Doc3  (0.9926, toxic web links help virus spread vir...
# Doc4  (0.9926, peer-to-peer nets  here to stay  peer...
# Doc5  (0.9926, peer-to-peer nets  here to stay  peer...
# Doc6  (0.9926, concerns over windows atms cash machi...
# Doc7  (0.9924, rich pickings for hi-tech thieves vir...
# Doc8  (0.991, security scares spark browser fix micr...
# Doc9  (0.9908, firefox browser takes on microsoft mi...
#
#                                                  Topic5
# Doc0  (0.9966, critics back aviator for oscars marti...
# Doc1  (0.9936, the producers scoops stage awards the...
# Doc2  (0.9923, eastwood s baby scoops top oscars cli...
# Doc3  (0.9918, aviator and vera take bafta glory hol...
# Doc4  (0.9907, british stars denied major oscars bri...
# Doc5  (0.9899, vera drake s bafta triumph hope at th...
# Doc6  (0.9898, bafta to hand out movie honours movie...
# Doc7  (0.9897, foxx and swank take actors awards jam...
# Doc8  (0.9897, grammys honour soul star charles the ...
# Doc9  (0.9895, foxx and swank win us awards jamie fo...

# %%
# get perplexity for optimal number of topics
perplexity5 = perplexity5.loc[perplexity5['Number Of Topics'] == optimal_num_topics5, 'Perplexity Score'].values[0]
lda_dict[mod_name]['perplexity'] = perplexity5

# put the results into a dictionary
lda_dict[mod_name]['optimal_num_topics'] = optimal_num_topics5
lda_dict[mod_name]['W_df'] = W_df5
lda_dict[mod_name]['H_df'] = H_df5

# %% [markdown]
# ### LDA Model 6 {'number_features': 1000, 'vec_max_df': 0.02, 'vec_min_df': 12}

# %%
mod_name = 'lda6'

# add parameters to dictionary
lda_dict[mod_name] = {
    'number_features': 1000,
    'vec_max_df': 0.02,
    'vec_min_df': 12
}

# %%
# perform bag of words conversion
vectorizer6, clean_vec6, feature_names_vec6 = do_bag_of_words_conversion(
    clean_sentences,
    lda_dict[mod_name]['vec_max_df'],
    lda_dict[mod_name]['vec_min_df'],
    lda_dict[mod_name]['number_features']
    )

# get perplexity and plot
perplexity6, optimal_num_topics6 = get_perplexity_and_plot(clean_vec6, 10)
# Out:
#    Number Of Topics  Perplexity Score
# 0                 1       1006.919845
# 1                 2        908.154543
# 2                 3        883.389881
# 3                 4        865.496003
# 4                 5        863.829785
# 5                 6        817.284442
# 6                 7        826.293538
# 7                 8        791.327090
# 8                 9        796.450217
# 9                10        806.293025
#
#
# Optimal Number of Topics: 8

# %%
# run the do_lda function
lda6, lda_transform6, lda_components6 = do_lda(
    clean_vec6,
    optimal_num_topics6
    )

# get nice tables
W_df6, H_df6 = get_topics(
    mod=lda6,
    vec=clean_vec6,
    names=feature_names_vec6,
    docs=raw,
    ndocs=number_docs,
    nwords=number_words
    )

# %%
# word topic table: top 10 words for each topic
W_df6
# Out:
#                         Topic0               Topic1              Topic2  \
# Word0       (0.0268, campbell)     (0.0296, google)   (0.0426, airline)
# Word1       (0.0223, ferguson)     (0.0175, engine)    (0.034, roddick)
# Word2  (0.022, highdefinition)     (0.0149, infect)   (0.0291, handset)
# Word3       (0.0198, mourinho)    (0.0148, spyware)  (0.0207, nintendo)
# Word4         (0.0188, poster)     (0.0137, laptop)    (0.0204, hewitt)
# Word5         (0.0171, format)      (0.0132, yahoo)    (0.0185, gamers)
# Word6          (0.0159, email)   (0.0129, musician)   (0.0156, concert)
# Word7           (0.015, henry)  (0.0127, malicious)   (0.0151, federer)
# Word8         (0.012, everton)      (0.0125, novel)     (0.015, sister)
# Word9          (0.0113, blues)    (0.0124, browser)  (0.0142, republic)
#
#                     Topic3                Topic4               Topic5  \
# Word0     (0.0167, asylum)      (0.0179, clarke)      (0.0364, yukos)
# Word1    (0.0121, minimum)       (0.0171, straw)   (0.0206, deutsche)
# Word2      (0.012, advice)      (0.0156, terror)     (0.0195, athens)
# Word3     (0.0094, border)     (0.015, blunkett)     (0.0191, holmes)
# Word4   (0.009, developer)      (0.0139, arrest)    (0.0171, auction)
# Word5      (0.0083, steel)       (0.013, prince)      (0.0167, medal)
# Word6     (0.0078, piracy)  (0.0129, supporting)     (0.0165, indoor)
# Word7  (0.0073, copyright)       (0.0126, globe)  (0.0158, athletics)
# Word8     (0.0073, pirate)    (0.0125, sideways)  (0.0152, insurance)
# Word9      (0.0072, pupil)       (0.0123, hotel)      (0.0147, welsh)
#
#                     Topic6                   Topic7
# Word0   (0.0151, worldcom)        (0.0102, poverty)
# Word1    (0.0138, brother)          (0.0096, korea)
# Word2    (0.0137, lawsuit)        (0.0095, housing)
# Word3     (0.0135, wenger)          (0.0095, index)
# Word4   (0.0127, creditor)        (0.009, mortgage)
# Word5    (0.0121, vehicle)       (0.0087, currency)
# Word6     (0.0116, recall)  (0.0085, manufacturing)
# Word7    (0.0115, factory)     (0.0082, leadership)
# Word8     (0.0114, muslim)       (0.0079, slowdown)
# Word9  (0.0112, celebrity)         (0.0079, import)

# %%
# document topic table: top 10 documents for each topic
H_df6
# Out:
#                                                  Topic0  \
# Doc0  (0.9757, what high-definition will do to dvds ...
# Doc1  (0.9757, what high-definition will do to dvds ...
# Doc2  (0.9698, bridge could miss rest of season chel...
# Doc3  (0.9602, lions blow to world cup winners briti...
# Doc4  (0.9602, lions blow to world cup stars british...
# Doc5  (0.9562, ferguson urges henry punishment sir a...
# Doc6  (0.9453, mourinho defiant on chelsea form chel...
# Doc7  (0.9416, charvis set to lose fitness bid flank...
# Doc8  (0.9416, stam spices up man utd encounter ac m...
# Doc9  (0.9384, gadget market  to grow in 2005  the e...
#
#                                                  Topic1  \
# Doc0  (0.988, apple laptop is  greatest gadget  the ...
# Doc1  (0.9846, apple laptop is  greatest gadget  the...
# Doc2  (0.975, security scares spark browser fix micr...
# Doc3  (0.9698, firefox browser takes on microsoft mi...
# Doc4  (0.9676, microsoft debuts security tools micro...
# Doc5  (0.965, virus poses as christmas e-mail securi...
# Doc6  (0.965, virus poses as christmas e-mail securi...
# Doc7  (0.965, blog  picked as word of the year the t...
# Doc8  (0.9635, digital guru floats sub-$100 pc nicho...
# Doc9  (0.9635, digital guru floats sub-$100 pc nicho...
#
#                                                  Topic2  \
# Doc0  (0.9914, nadal puts spain 2-0 up result: nadal...
# Doc1  (0.9857, henman to face saulnier test british ...
# Doc2  (0.9844, irish finish with home game republic ...
# Doc3  (0.9743, hewitt fights back to reach final lle...
# Doc4  (0.9735, lifestyle  governs mobile choice  fas...
# Doc5  (0.9735, lifestyle  governs mobile choice  fas...
# Doc6  (0.9717, camera phones are  must-haves  four t...
# Doc7  (0.9717, camera phones are  must-haves  four t...
# Doc8  (0.9698, nintendo handheld given euro date nin...
# Doc9  (0.9602, faultless federer has no equal roger ...
#
#                                                  Topic3  \
# Doc0  (0.9743, blair rejects iraq advice calls tony ...
# Doc1  (0.9698, tories outlining policing plans local...
# Doc2  (0.9687, pompeii gets digital make-over the ol...
# Doc3  (0.9676, peer-to-peer nets  here to stay  peer...
# Doc4  (0.9676, peer-to-peer nets  here to stay  peer...
# Doc5  (0.9562, bt program to beat dialler scams bt i...
# Doc6  (0.9485, brown outlines third term vision gord...
# Doc7  (0.9485, brown outlines third term vision gord...
# Doc8  (0.9452, tv station refuses adoption show a tv...
# Doc9  (0.9334, iraq advice claim sparks new row the ...
#
#                                                  Topic4  \
# Doc0  (0.9907, critics back aviator for oscars marti...
# Doc1  (0.9801, aviator and vera take bafta glory hol...
# Doc2  (0.975, royal couple watch nation s mood princ...
# Doc3  (0.9726, hollywood ready for oscars night holl...
# Doc4  (0.9726, bafta to hand out movie honours movie...
# Doc5  (0.9708, blair defends terror law changes the ...
# Doc6  (0.9676, blair rejects tory terror offer tony ...
# Doc7  (0.9663, stars gear up for bafta ceremony film...
# Doc8  (0.965, clarke to press on with id cards new h...
# Doc9  (0.9619, howard denies split over id cards mic...
#
#                                                  Topic5  \
# Doc0  (0.9854, britain boosted by holmes double athl...
# Doc1  (0.9828, yukos unit fetches $9bn at auction a ...
# Doc2  (0.9805, what now for kelly holmes  last april...
# Doc3  (0.977, wales win in rome wales secured their ...
# Doc4  (0.9763, deutsche attacks yukos case german in...
# Doc5  (0.9708, greek sprinters suspended by iaaf gre...
# Doc6  (0.9676, verdict delay for greek sprinters gre...
# Doc7  (0.9676, o driscoll saves irish blushes two mo...
# Doc8  (0.9663, jones happy with henson heroics wales...
# Doc9  (0.965, iaaf to rule on greek sprint pair gree...
#
#                                                  Topic6  \
# Doc0  (0.9757, worldcom director admits lying the fo...
# Doc1  (0.9757, worldcom ex-boss launches defence law...
# Doc2  (0.9742, us state acts to stop  spammers  us s...
# Doc3  (0.9727, worldcom boss  left books alone  form...
# Doc4  (0.9687, worldcom director ends evidence the f...
# Doc5  (0.9602, wenger rules out new keeper arsenal b...
# Doc6  (0.9602, pm apology over jailings tony blair h...
# Doc7  (0.9562, boris opposes mayor apology ken livin...
# Doc8  (0.9539, no jail for singer courtney love sing...
# Doc9  (0.9539, bmw to recall faulty diesel cars bmw ...
#
#                                                  Topic7
# Doc0  (0.9698, s korea spending boost to economy sou...
# Doc1  (0.9698, debate needed  on donations cap a cap...
# Doc2  (0.9698, debate needed  on donations cap a cap...
# Doc3  (0.9687, uk interest rates held at 4.75% the b...
# Doc4  (0.9676, asian banks halt dollar s slide the d...
# Doc5  (0.965, dollar drops on reserves concerns the ...
# Doc6  (0.9619, us retail sales surge in december us ...
# Doc7  (0.9602, firms pump billions into pensions emp...
# Doc8  (0.9602, no seasonal lift for house market a s...
# Doc9  (0.9602, japan economy slides to recession the...

# %%
# get perplexity for optimal number of topics
perplexity6 = perplexity6.loc[perplexity6['Number Of Topics'] == optimal_num_topics6, 'Perplexity Score'].values[0]
lda_dict[mod_name]['perplexity'] = perplexity6

# put the results into a dictionary
lda_dict[mod_name]['optimal_num_topics'] = optimal_num_topics6
lda_dict[mod_name]['W_df'] = W_df6
lda_dict[mod_name]['H_df'] = H_df6

# %% [markdown]
# ### Summary of LDA models

# %%
# to display the results
lda_t = PrettyTable()

lda_t.field_names = [
    "Model Name",
    "Optimal Number Of Topics",
    "Number Of Features",
    "Vector Max DF",
    "Vector Min DF",
    "Perplexity"
]

# loop through the models
for mod_name, mod_dict in lda_dict.items():
    # get the parameters
    num_topics = mod_dict['optimal_num_topics']
    num_features = mod_dict['number_features']
    vec_max_df = mod_dict['vec_max_df']
    vec_min_df = mod_dict['vec_min_df']
    perplexity = round(mod_dict['perplexity'], 2)

    # add a row to the table
    lda_t.add_row([
        mod_name,
        num_topics,
        num_features,
        vec_max_df,
        vec_min_df,
        perplexity
    ])

# print the table
print(lda_t)
# Out:
# +------------+--------------------------+--------------------+---------------+---------------+------------+
# | Model Name | Optimal Number Of Topics | Number Of Features | Vector Max DF | Vector Min DF | Perplexity |
# +------------+--------------------------+--------------------+---------------+---------------+------------+
# |    lda1    |            7             |        1500        |      0.05     |       20      |   755.74   |
# |    lda2    |            4             |        1750        |      0.05     |       12      |  1141.68   |
# |    lda3    |            3             |        1500        |      0.02     |       15      |   854.0    |
# |    lda4    |            5             |        1250        |      0.1      |       15      |   723.03   |
# |    lda5    |            6             |        1250        |      0.1      |       7       |   700.95   |
# |    lda6    |            8             |        1000        |      0.02     |       12      |   791.33   |
# +------------+--------------------------+--------------------+---------------+---------------+------------+

# %%
# plot the t-sne for all the models
print("LDA Model 1 "+"-"*100)
plt.figure(figsize=(4, 3))
plot_tsne(data=lda_transform1, threshold=0.6)
plt.show()

print("LDA Model 2 "+"-"*100)
plt.figure(figsize=(4, 3))
plot_tsne(data=lda_transform2, threshold=0.6)
plt.show()

print("LDA Model 3 "+"-"*100)
plt.figure(figsize=(4, 3))
plot_tsne(data=lda_transform3, threshold=0.6)
plt.show()

print("LDA Model 4 "+"-"*100)
plt.figure(figsize=(4, 3))
plot_tsne(data=lda_transform4, threshold=0.6)
plt.show()

print("LDA Model 5 "+"-"*100)
plt.figure(figsize=(4, 3))
plot_tsne(data=lda_transform5, threshold=0.6)
plt.show()

print("LDA Model 6 "+"-"*100)
plt.figure(figsize=(4, 3))
plot_tsne(data=lda_transform6, threshold=0.6)
plt.show()
# Out:
# LDA Model 1 ----------------------------------------------------------------------------------------------------
# LDA Model 2 ----------------------------------------------------------------------------------------------------
# LDA Model 3 ----------------------------------------------------------------------------------------------------
# LDA Model 4 ----------------------------------------------------------------------------------------------------
# LDA Model 5 ----------------------------------------------------------------------------------------------------
# LDA Model 6 ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## NMF Models

# %%
number_features = 1000

# %%
# convert to bag of words model
# use tf-idf method this time
vectorizer = sklearn.feature_extraction.text.TfidfVectorizer(
    analyzer="word",
    max_df=0.5,    # ignore words that appear in max_df% of documents
    min_df=20,    # ignore words that appear in less than min_df documents
    max_features=number_features,
    smooth_idf=False
)
tfidf = vectorizer.fit_transform(clean_sentences)

# %%
tfidf
# Out:
# <1490x1000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 46485 stored elements in Compressed Sparse Row format>

# %%
vectorizer
# Out:
# TfidfVectorizer(max_df=0.5, max_features=1000, min_df=20, smooth_idf=False)

# %%
feature_names_vect = vectorizer.get_feature_names()

# %%
# define and fit nmf model1

nmf_model1 = sklearn.decomposition.NMF(
    n_components=7,
    init="nndsvd",
    solver="mu",
    beta_loss="frobenius",
    random_state=0,
    alpha=0.1,
    l1_ratio=0.2
)
nmf_model1.fit(tfidf)
# Out:
# NMF(alpha=0.1, init='nndsvd', l1_ratio=0.2, n_components=7, random_state=0,
#     solver='mu')

# %%
# second nfm model
nmf_model2 = sklearn.decomposition.NMF(
    n_components=4,
    init="random",
    solver="mu",
    beta_loss="frobenius",
    random_state=42,
    alpha=0.01,
    l1_ratio=0.3
)
nmf_model2.fit(tfidf)
# Out:
# NMF(alpha=0.01, init='random', l1_ratio=0.3, n_components=4, random_state=42,
#     solver='mu')

# %%
# third nfm model
nmf_model3 = sklearn.decomposition.NMF(
    n_components=9,
    init="random",
    solver="cd",
    beta_loss="frobenius",
    random_state=20,
    alpha=0.1,
    l1_ratio=0.2
)
nmf_model3.fit(tfidf)
# Out:
# NMF(alpha=0.1, init='random', l1_ratio=0.2, n_components=9, random_state=20)

# %%
# fouth nfm model
nmf_model4 = sklearn.decomposition.NMF(
    n_components=3,
    init="nndsvda",
    solver="mu",
    beta_loss="kullback-leibler",
    random_state=42,
    alpha=0.01,
    l1_ratio=0.4
)
nmf_model4.fit(tfidf)
# Out:
# NMF(alpha=0.01, beta_loss='kullback-leibler', init='nndsvda', l1_ratio=0.4,
#     n_components=3, random_state=42, solver='mu')

# %%
# fifth nfm model

nmf_model5 = sklearn.decomposition.NMF(
    n_components=6,
    init="random",
    solver="cd",
    beta_loss="frobenius",
    random_state=42,
    alpha=0.1,
    l1_ratio=0.1
)
nmf_model5.fit(tfidf)
# Out:
# NMF(alpha=0.1, init='random', l1_ratio=0.1, n_components=6, random_state=42)

# %%
# sixth nfm model

nmf_model6 = sklearn.decomposition.NMF(
    n_components=8,
    init="nndsvd",
    solver="mu",
    beta_loss="kullback-leibler",
    random_state=42,
    alpha=0.1,
    l1_ratio=0.2
)
nmf_model6.fit(tfidf)
# Out:
# NMF(alpha=0.1, beta_loss='kullback-leibler', init='nndsvd', l1_ratio=0.2,
#     n_components=8, random_state=42, solver='mu')

# %%
all_nfm_models = [nmf_model1, nmf_model2, nmf_model3, nmf_model4, nmf_model5, nmf_model6]

# %% [markdown]
# ### Summary of NMF models

# %%
all_nfm_models
# Out:
# [NMF(alpha=0.1, init='nndsvd', l1_ratio=0.2, n_components=7, random_state=0,
#      solver='mu'),
#  NMF(alpha=0.01, init='random', l1_ratio=0.3, n_components=4, random_state=42,
#      solver='mu'),
#  NMF(alpha=0.1, init='random', l1_ratio=0.2, n_components=9, random_state=20),
#  NMF(alpha=0.01, beta_loss='kullback-leibler', init='nndsvda', l1_ratio=0.4,
#      n_components=3, random_state=42, solver='mu'),
#  NMF(alpha=0.1, init='random', l1_ratio=0.1, n_components=6, random_state=42),
#  NMF(alpha=0.1, beta_loss='kullback-leibler', init='nndsvd', l1_ratio=0.2,
#      n_components=8, random_state=42, solver='mu')]

# %%
# # nive output tables for all models
results_nmf=[]
for i, nmf_model in enumerate(all_nfm_models):
    W_df, H_df = get_topics(
        mod=nmf_model,
        vec=tfidf,
        names=feature_names_vect,
        docs=raw,
        ndocs=number_docs,
        nwords=number_words
    )
    W_df.to_csv(f'W_df_model{i}.csv', index=False)
    H_df.to_csv(f'H_df_model{i}.csv', index=False)
    results_nmf.append((W_df, H_df))

# %%
for i, (W_df, _) in enumerate(results_nmf, start=1):
    print(f"\n--------------> Word topic tables for model{i}:\n")
    print(W_df)
    print()
# Out:
# --------------> Word topic tables for model1:
#
#                    Topic0                  Topic1              Topic2  \
# Word0    (0.0592, mobile)        (0.0626, labour)   (0.0626, england)
# Word1     (0.0332, music)          (0.051, blair)     (0.0395, wales)
# Word2     (0.0228, phone)         (0.0433, brown)   (0.0338, ireland)
# Word3    (0.0177, gadget)    (0.0238, chancellor)    (0.0307, france)
# Word4    (0.0136, camera)        (0.0238, howard)    (0.0247, nation)
# Word5   (0.0129, handset)  (0.0164, conservative)     (0.0245, coach)
# Word6  (0.0127, consumer)       (0.0159, britain)     (0.0242, rugby)
# Word7  (0.0113, download)       (0.0149, kennedy)   (0.024, robinson)
# Word8   (0.0105, devices)       (0.0125, liberal)  (0.0213, scotland)
# Word9     (0.0097, radio)      (0.0119, democrat)    (0.0193, injury)
#
#                      Topic3             Topic4                 Topic5  \
# Word0       (0.0759, award)    (0.0178, share)      (0.0446, chelsea)
# Word1       (0.0381, actor)   (0.0148, dollar)      (0.0297, arsenal)
# Word2       (0.0361, oscar)  (0.0134, analyst)     (0.0297, champion)
# Word3  (0.0254, nomination)  (0.0133, profits)      (0.02, liverpool)
# Word4     (0.0253, actress)    (0.0108, stock)       (0.0159, madrid)
# Word5        (0.019, prize)    (0.0091, rates)      (0.0155, olympic)
# Word6    (0.0183, ceremony)   (0.0088, figure)      (0.014, ferguson)
# Word7      (0.0178, comedy)  (0.0088, deficit)   (0.0131, manchester)
# Word8     (0.0177, aviator)    (0.0086, costs)        (0.0128, title)
# Word9    (0.0161, category)   (0.0086, export)  (0.0127, premiership)
#
#                    Topic6
# Word0   (0.046, software)
# Word1  (0.037, microsoft)
# Word2  (0.0325, computer)
# Word3     (0.0291, virus)
# Word4    (0.0253, search)
# Word5    (0.019, machine)
# Word6  (0.0187, internet)
# Word7   (0.0186, program)
# Word8   (0.0176, windows)
# Word9    (0.0144, google)
#
#
# --------------> Word topic tables for model2:
#
#                        Topic0              Topic1                Topic2  \
# Word0         (0.045, labour)     (0.03, england)       (0.0555, award)
# Word1         (0.0368, blair)     (0.0182, wales)       (0.0276, actor)
# Word2         (0.0311, brown)   (0.0161, ireland)       (0.0259, oscar)
# Word3        (0.0176, howard)    (0.0153, france)  (0.0184, nomination)
# Word4    (0.0171, chancellor)    (0.0146, injury)     (0.0182, actress)
# Word5       (0.0122, britain)  (0.0139, champion)       (0.0142, prize)
# Word6  (0.0121, conservative)     (0.0138, coach)      (0.0134, comedy)
# Word7        (0.011, kennedy)   (0.0118, chelsea)    (0.0134, ceremony)
# Word8       (0.0093, liberal)    (0.0115, nation)     (0.0128, aviator)
# Word9      (0.0089, democrat)     (0.0112, rugby)       (0.0127, album)
#
#                     Topic3
# Word0     (0.0158, mobile)
# Word1      (0.0093, music)
# Word2   (0.0084, software)
# Word3   (0.0081, consumer)
# Word4   (0.0076, computer)
# Word5    (0.0071, analyst)
# Word6      (0.0063, share)
# Word7      (0.0063, phone)
# Word8  (0.0063, microsoft)
# Word9     (0.0056, gadget)
#
#
# --------------> Word topic tables for model3:
#
#                        Topic0               Topic1                Topic2  \
# Word0        (0.0338, labour)      (0.0746, award)      (0.1424, mobile)
# Word1        (0.0277, howard)      (0.0385, actor)       (0.0552, phone)
# Word2         (0.0239, blair)      (0.0366, oscar)      (0.0318, gadget)
# Word3       (0.0166, kennedy)    (0.0256, actress)     (0.0315, handset)
# Word4  (0.0165, conservative)  (0.025, nomination)      (0.0294, camera)
# Word5       (0.0151, britain)      (0.0184, prize)       (0.0179, music)
# Word6       (0.0136, liberal)   (0.0181, ceremony)    (0.0178, operator)
# Word7      (0.0131, democrat)    (0.0178, aviator)     (0.0173, devices)
# Word8   (0.0121, immigration)     (0.0173, comedy)    (0.0168, consumer)
# Word9        (0.0111, asylum)   (0.0161, category)  (0.0133, multimedia)
#
#                    Topic3                Topic4                 Topic5  \
# Word0   (0.0621, england)       (0.1221, brown)      (0.0398, chelsea)
# Word1      (0.039, wales)      (0.0686, labour)     (0.0301, champion)
# Word2    (0.034, ireland)       (0.0644, blair)      (0.0265, arsenal)
# Word3    (0.0299, france)  (0.0593, chancellor)     (0.018, liverpool)
# Word4    (0.0246, nation)      (0.0284, gordon)      (0.0153, olympic)
# Word5  (0.0241, robinson)     (0.0179, milburn)        (0.015, madrid)
# Word6     (0.0239, rugby)     (0.0143, cabinet)       (0.0141, injury)
# Word7     (0.0224, coach)   (0.0118, manifesto)         (0.013, title)
# Word8   (0.021, scotland)    (0.0106, spending)     (0.0125, ferguson)
# Word9    (0.0166, injury)     (0.0104, poverty)  (0.0118, premiership)
#
#                     Topic6             Topic7             Topic8
# Word0   (0.0361, software)    (0.0715, music)    (0.0164, share)
# Word1  (0.0291, microsoft)    (0.0581, album)   (0.0135, dollar)
# Word2   (0.0278, computer)    (0.0391, chart)  (0.0131, analyst)
# Word3      (0.0212, virus)   (0.0218, singer)  (0.0124, profits)
# Word4     (0.0188, search)   (0.0177, artist)      (0.01, stock)
# Word5    (0.0162, machine)  (0.0165, singles)    (0.0087, rates)
# Word6   (0.0157, internet)    (0.0164, radio)   (0.0086, figure)
# Word7     (0.014, program)  (0.016, download)  (0.0082, deficit)
# Word8    (0.0132, windows)  (0.0137, concert)   (0.0081, export)
# Word9  (0.0121, broadband)    (0.0128, debut)     (0.008, costs)
#
#
# --------------> Word topic tables for model4:
#
#                    Topic0                  Topic1              Topic2
# Word0     (0.0089, music)        (0.0192, labour)   (0.0184, england)
# Word1     (0.0088, award)         (0.0166, blair)  (0.0138, champion)
# Word2    (0.0079, mobile)         (0.0136, brown)    (0.0124, injury)
# Word3     (0.0063, share)        (0.0105, howard)   (0.0116, chelsea)
# Word4   (0.0061, analyst)       (0.0076, britain)   (0.0113, ireland)
# Word5  (0.0058, computer)    (0.0073, chancellor)     (0.0111, wales)
# Word6  (0.0058, software)  (0.0071, conservative)     (0.011, france)
# Word7  (0.0055, consumer)    (0.0062, parliament)     (0.0101, coach)
# Word8     (0.0055, actor)      (0.0059, minister)     (0.0093, title)
# Word9    (0.0052, dollar)      (0.0059, proposal)     (0.0092, sport)
#
#
# --------------> Word topic tables for model5:
#
#                        Topic0                  Topic1                Topic2  \
# Word0        (0.0482, labour)       (0.0345, chelsea)       (0.0582, award)
# Word1         (0.0396, blair)      (0.0274, champion)        (0.029, actor)
# Word2         (0.0333, brown)       (0.0232, arsenal)       (0.0272, oscar)
# Word3        (0.0188, howard)     (0.0159, liverpool)  (0.0192, nomination)
# Word4    (0.0183, chancellor)       (0.0144, olympic)     (0.0191, actress)
# Word5       (0.0129, britain)        (0.0135, madrid)       (0.0147, prize)
# Word6  (0.0129, conservative)        (0.0129, injury)     (0.014, ceremony)
# Word7       (0.0117, kennedy)         (0.0122, title)      (0.0139, comedy)
# Word8       (0.0098, liberal)      (0.0111, ferguson)     (0.0134, aviator)
# Word9      (0.0094, democrat)  (0.0106, championship)    (0.0124, category)
#
#                   Topic3              Topic4              Topic5
# Word0    (0.0138, share)    (0.0451, mobile)   (0.0582, england)
# Word1   (0.011, analyst)     (0.0245, music)     (0.0366, wales)
# Word2   (0.0109, dollar)     (0.0178, phone)   (0.0319, ireland)
# Word3  (0.0103, profits)  (0.0155, software)     (0.028, france)
# Word4    (0.0085, stock)    (0.0143, gadget)    (0.0232, nation)
# Word5   (0.0073, figure)  (0.0135, computer)  (0.0226, robinson)
# Word6    (0.0071, rates)  (0.013, microsoft)     (0.0225, rugby)
# Word7     (0.007, costs)  (0.0108, download)      (0.021, coach)
# Word8   (0.0067, export)    (0.0106, camera)  (0.0199, scotland)
# Word9  (0.0067, deficit)  (0.0106, consumer)    (0.0155, injury)
#
#
# --------------> Word topic tables for model6:
#
#                     Topic0                  Topic1              Topic2  \
# Word0     (0.0148, mobile)        (0.0423, labour)   (0.0415, england)
# Word1  (0.0068, programme)         (0.0361, blair)     (0.0264, wales)
# Word2     (0.0061, gadget)         (0.0278, brown)     (0.024, france)
# Word3      (0.0061, phone)        (0.0199, howard)   (0.0228, ireland)
# Word4    (0.006, consumer)    (0.0157, chancellor)     (0.0227, coach)
# Word5     (0.0054, launch)  (0.0146, conservative)    (0.0225, injury)
# Word6     (0.0049, camera)       (0.0143, britain)  (0.0197, scotland)
# Word7    (0.0048, predict)       (0.0121, kennedy)     (0.0168, rugby)
# Word8   (0.0047, standard)       (0.0111, liberal)  (0.0166, williams)
# Word9    (0.0046, console)       (0.011, democrat)    (0.0147, nation)
#
#                      Topic3              Topic4               Topic5  \
# Word0       (0.0585, award)      (0.017, share)    (0.0235, chelsea)
# Word1       (0.0345, actor)   (0.0133, analyst)     (0.02, champion)
# Word2       (0.0273, oscar)    (0.0125, dollar)    (0.0181, arsenal)
# Word3     (0.025, festival)    (0.012, profits)    (0.0152, olympic)
# Word4      (0.0208, comedy)   (0.0102, airline)  (0.0143, liverpool)
# Word5     (0.0208, actress)     (0.0102, stock)  (0.014, manchester)
# Word6         (0.02, movie)      (0.009, costs)   (0.0127, football)
# Word7       (0.0189, prize)  (0.0089, investor)     (0.0126, madrid)
# Word8  (0.0183, nomination)    (0.0089, figure)      (0.0122, trial)
# Word9   (0.0156, hollywood)    (0.0088, export)   (0.0114, ferguson)
#
#                     Topic6               Topic7
# Word0   (0.0314, software)      (0.0477, music)
# Word1   (0.0264, computer)      (0.0354, album)
# Word2  (0.0228, microsoft)       (0.031, chart)
# Word3   (0.0221, internet)     (0.0267, singer)
# Word4     (0.0217, search)    (0.0161, singles)
# Word5    (0.02, broadband)     (0.0153, artist)
# Word6      (0.0195, virus)    (0.0152, tsunami)
# Word7    (0.0155, version)     (0.0143, record)
# Word8    (0.0144, machine)    (0.0141, concert)
# Word9     (0.0129, google)  (0.0137, christmas)

# %%
for i, (_, H_df) in enumerate(results_nmf, start=1):
    print(f"\n----------------->Document-topic table for model {i}:\n")
    print(H_df)
# Out:
# ----------------->Document-topic table for model 1:
#
#                                                  Topic0  \
# Doc0  (0.3356, mobile music challenges  ipod age  no...
# Doc1  (0.3336, mobiles  not media players yet  mobil...
# Doc2  (0.3336, mobiles  not media players yet  mobil...
# Doc3  (0.3223, looks and music to drive mobiles mobi...
# Doc4  (0.3223, looks and music to drive mobiles mobi...
# Doc5  (0.3029, mobiles rack up 20 years of use mobil...
# Doc6  (0.3029, mobiles rack up 20 years of use mobil...
# Doc7  (0.3003, half of uk s mobiles  go online  mult...
# Doc8  (0.2887, friends fear  with lost mobiles peopl...
# Doc9  (0.2866, mobile gig aims to rock 3g forget abo...
#
#                                                  Topic1  \
# Doc0  (0.3173, blair pledges unity to labour mps ton...
# Doc1  (0.3094, blair stresses prosperity goals tony ...
# Doc2  (0.3038, blair and brown criticised by mps lab...
# Doc3  (0.299, blair labour s longest-serving pm tony...
# Doc4  (0.2984, labour mp praises tory campaign the c...
# Doc5  (0.2885, brown outlines third term vision gord...
# Doc6  (0.2885, brown outlines third term vision gord...
# Doc7  (0.2826, howard taunts blair over splits tony ...
# Doc8  (0.2822, brown  proud of economy record  gordo...
# Doc9  (0.281, labour seeks to quell feud talk labour...
#
#                                                  Topic2  \
# Doc0  (0.3156, celts savour grand slam prospect the ...
# Doc1  (0.2906, ireland 19-13 england ireland consign...
# Doc2  (0.2905, bell set for england debut bath prop ...
# Doc3  (0.2885, castaignede fires laporte warning for...
# Doc4  (0.283, preview: ireland v england (sun) lansd...
# Doc5  (0.2781, a november to remember last saturday ...
# Doc6  (0.2704, dominici backs lacklustre france wing...
# Doc7  (0.2669, england given tough sevens draw engla...
# Doc8  (0.2547, harinordoquy suffers france axe numbe...
# Doc9  (0.2545, italy aim to rattle england italy coa...
#
#                                                  Topic3  \
# Doc0  (0.3218, spirit awards hail sideways the comed...
# Doc1  (0.3185, sideways dominates spirit awards the ...
# Doc2  (0.3004, aviator and vera take bafta glory hol...
# Doc3  (0.298, bafta to hand out movie honours movie ...
# Doc4  (0.2933, foxx and swank win us awards jamie fo...
# Doc5  (0.2927, vera drake s bafta triumph hope at th...
# Doc6  (0.2925, foxx and swank take actors awards jam...
# Doc7  (0.285, british stars denied major oscars brit...
# Doc8  (0.2844, wine comedy wins critics  award quirk...
# Doc9  (0.2766, stars gear up for bafta ceremony film...
#
#                                                  Topic4  \
# Doc0  (0.2043, ore costs hit global steel firms shar...
# Doc1  (0.1982, car giant hit by mercedes slump a slu...
# Doc2  (0.185, australia rates at four year high aust...
# Doc3  (0.1781, air china in $1bn london listing chin...
# Doc4  (0.1775, us adds more jobs than expected the u...
# Doc5  (0.1762, strong dollar  call halts slide the u...
# Doc6  (0.1757, dollar hovers around record lows the ...
# Doc7  (0.1742, qwest may spark mci bidding war us ph...
# Doc8  (0.1738, hariri killing hits beirut shares sha...
# Doc9  (0.1677, shares hit by ms drug suspension shar...
#
#                                                  Topic5  \
# Doc0  (0.2613, desailly backs blues revenge trip mar...
# Doc1  (0.2612, mourinho defiant on chelsea form chel...
# Doc2  (0.2599, mourinho plots impressive course chel...
# Doc3  (0.2492, chelsea hold arsenal a gripping game ...
# Doc4  (0.2475, mourinho takes swipe at arsenal chels...
# Doc5  (0.2473, gallas sees two-horse race chelsea s ...
# Doc6  (0.2396, adriano s chelsea link rejected adria...
# Doc7  (0.2307, english clubs make euro history all f...
# Doc8  (0.2303, cup holders man utd visit everton hol...
# Doc9  (0.2233, gerrard plays down european hopes ste...
#
#                                                  Topic6
# Doc0  (0.3379, microsoft debuts security tools micro...
# Doc1  (0.287, microsoft makes anti-piracy move micro...
# Doc2  (0.2869, search wars hit desktop pcs another f...
# Doc3  (0.2846, microsoft seeking spyware trojan micr...
# Doc4  (0.2846, microsoft seeking spyware trojan micr...
# Doc5  (0.2672, microsoft takes on desktop search mic...
# Doc6  (0.2669, microsoft releases bumper patches mic...
# Doc7  (0.255, microsoft sets sights on spyware windo...
# Doc8  (0.2513, uk gets official virus alert site a r...
# Doc9  (0.2502, the pirates with no profit motive two...
#
# ----------------->Document-topic table for model 2:
#
#                                                  Topic0  \
# Doc0  (0.3431, blair pledges unity to labour mps ton...
# Doc1  (0.3344, blair stresses prosperity goals tony ...
# Doc2  (0.3287, blair and brown criticised by mps lab...
# Doc3  (0.3228, blair labour s longest-serving pm ton...
# Doc4  (0.3213, labour mp praises tory campaign the c...
# Doc5  (0.3137, brown outlines third term vision gord...
# Doc6  (0.3137, brown outlines third term vision gord...
# Doc7  (0.308, brown  proud of economy record  gordon...
# Doc8  (0.3075, howard taunts blair over splits tony ...
# Doc9  (0.306, labour seeks to quell feud talk labour...
#
#                                                  Topic1  \
# Doc0  (0.297, celts savour grand slam prospect the s...
# Doc1  (0.2672, bell set for england debut bath prop ...
# Doc2  (0.2629, a november to remember last saturday ...
# Doc3  (0.2628, ireland 19-13 england ireland consign...
# Doc4  (0.2565, preview: ireland v england (sun) lans...
# Doc5  (0.2563, castaignede fires laporte warning for...
# Doc6  (0.2556, dominici backs lacklustre france wing...
# Doc7  (0.2362, italy aim to rattle england italy coa...
# Doc8  (0.234, england given tough sevens draw englan...
# Doc9  (0.2312, ireland win eclipses refereeing  erro...
#
#                                                  Topic2  \
# Doc0  (0.3379, spirit awards hail sideways the comed...
# Doc1  (0.3345, sideways dominates spirit awards the ...
# Doc2  (0.3205, aviator and vera take bafta glory hol...
# Doc3  (0.3133, bafta to hand out movie honours movie...
# Doc4  (0.3087, foxx and swank win us awards jamie fo...
# Doc5  (0.308, vera drake s bafta triumph hope at the...
# Doc6  (0.3077, foxx and swank take actors awards jam...
# Doc7  (0.299, british stars denied major oscars brit...
# Doc8  (0.2979, wine comedy wins critics  award quirk...
# Doc9  (0.2922, aviator wins top globes accolades the...
#
#                                                  Topic3
# Doc0  (0.2042, looks and music to drive mobiles mobi...
# Doc1  (0.2042, looks and music to drive mobiles mobi...
# Doc2  (0.2036, mobiles  not media players yet  mobil...
# Doc3  (0.2036, mobiles  not media players yet  mobil...
# Doc4  (0.2012, mobile music challenges  ipod age  no...
# Doc5  (0.1939, the future in your pocket if you are ...
# Doc6  (0.1849, apple ipod family expands market appl...
# Doc7  (0.1841, friends fear  with lost mobiles peopl...
# Doc8  (0.1812, gadget growth fuels eco concerns tech...
# Doc9  (0.1776, half of uk s mobiles  go online  mult...
#
# ----------------->Document-topic table for model 3:
#
#                                                  Topic0  \
# Doc0  (0.2652, howard unveils election platform the ...
# Doc1  (0.2643, howard and blair tax pledge clash ton...
# Doc2  (0.2613, kennedy begins pre-election tour libe...
# Doc3  (0.2544, tories urge  change at the top  tory ...
# Doc4  (0.2542, fox attacks blair s tory  lies  tony ...
# Doc5  (0.2542, fox attacks blair s tory  lies  tony ...
# Doc6  (0.2517, mrs howard gets key election role mic...
# Doc7  (0.2477, uk needs tax cuts  tories insist a ma...
# Doc8  (0.2469, lib dems unveil election slogan the l...
# Doc9  (0.2444, uk heading wrong way  says howard ton...
#
#                                                  Topic1  \
# Doc0  (0.3278, spirit awards hail sideways the comed...
# Doc1  (0.3243, sideways dominates spirit awards the ...
# Doc2  (0.309, aviator and vera take bafta glory holl...
# Doc3  (0.3074, bafta to hand out movie honours movie...
# Doc4  (0.3027, foxx and swank win us awards jamie fo...
# Doc5  (0.302, foxx and swank take actors awards jami...
# Doc6  (0.2999, vera drake s bafta triumph hope at th...
# Doc7  (0.2929, wine comedy wins critics  award quirk...
# Doc8  (0.2927, british stars denied major oscars bri...
# Doc9  (0.2863, stars gear up for bafta ceremony film...
#
#                                                  Topic2  \
# Doc0  (0.3875, mobiles rack up 20 years of use mobil...
# Doc1  (0.3875, mobiles rack up 20 years of use mobil...
# Doc2  (0.379, half of uk s mobiles  go online  multi...
# Doc3  (0.3652, friends fear  with lost mobiles peopl...
# Doc4  (0.3611, home phones face unclear future the f...
# Doc5  (0.3558, mobiles  not media players yet  mobil...
# Doc6  (0.3558, mobiles  not media players yet  mobil...
# Doc7  (0.3432, mobile gaming takes off in india gami...
# Doc8  (0.3303, finding new homes for old phones re-u...
# Doc9  (0.3161, text message record smashed uk mobile...
#
#                                                  Topic3  \
# Doc0  (0.3154, celts savour grand slam prospect the ...
# Doc1  (0.298, ireland 19-13 england ireland consigne...
# Doc2  (0.2961, bell set for england debut bath prop ...
# Doc3  (0.2937, castaignede fires laporte warning for...
# Doc4  (0.2904, preview: ireland v england (sun) lans...
# Doc5  (0.2804, a november to remember last saturday ...
# Doc6  (0.2739, england given tough sevens draw engla...
# Doc7  (0.2694, dominici backs lacklustre france wing...
# Doc8  (0.2591, italy aim to rattle england italy coa...
# Doc9  (0.2582, harinordoquy suffers france axe numbe...
#
#                                                  Topic4  \
# Doc0  (0.3806, blair and brown criticised by mps lab...
# Doc1  (0.3803, profile: gordon brown the ultimate pr...
# Doc2  (0.3462, blair stresses prosperity goals tony ...
# Doc3  (0.3456, blair  said he would stand down  tony...
# Doc4  (0.3454, labour seeks to quell feud talk labou...
# Doc5  (0.3423, blair pledges unity to labour mps ton...
# Doc6  (0.334, brown outlines third term vision gordo...
# Doc7  (0.334, brown outlines third term vision gordo...
# Doc8  (0.3291, blair dismisses quit claim report ton...
# Doc9  (0.3083, brown s poll campaign move denied the...
#
#                                                  Topic5  \
# Doc0  (0.2552, mourinho plots impressive course chel...
# Doc1  (0.2548, desailly backs blues revenge trip mar...
# Doc2  (0.2501, mourinho defiant on chelsea form chel...
# Doc3  (0.2387, gallas sees two-horse race chelsea s ...
# Doc4  (0.2351, chelsea hold arsenal a gripping game ...
# Doc5  (0.2347, mourinho takes swipe at arsenal chels...
# Doc6  (0.226, adriano s chelsea link rejected adrian...
# Doc7  (0.2255, english clubs make euro history all f...
# Doc8  (0.2209, cup holders man utd visit everton hol...
# Doc9  (0.22, gerrard plays down european hopes steve...
#
#                                                  Topic6  \
# Doc0  (0.3143, microsoft debuts security tools micro...
# Doc1  (0.2693, search wars hit desktop pcs another f...
# Doc2  (0.2672, microsoft makes anti-piracy move micr...
# Doc3  (0.2653, microsoft seeking spyware trojan micr...
# Doc4  (0.2653, microsoft seeking spyware trojan micr...
# Doc5  (0.2596, mac mini heralds mini revolution the ...
# Doc6  (0.252, microsoft takes on desktop search micr...
# Doc7  (0.248, microsoft releases bumper patches micr...
# Doc8  (0.2468, uk gets official virus alert site a r...
# Doc9  (0.2456, the pirates with no profit motive two...
#
#                                                  Topic7  \
# Doc0  (0.3225, uk  world s biggest music buyer  uk c...
# Doc1  (0.2786, u2 s desire to be number one u2  who ...
# Doc2  (0.2735, brits return keane to number one brit...
# Doc3  (0.2723, franz man seeks government help franz...
# Doc4  (0.2677, black sabbath top rock album poll bla...
# Doc5  (0.2578, duran duran show set for us tv chart ...
# Doc6  (0.2553, roxy music on isle of wight bill roxy...
# Doc7  (0.2528, portishead back after eight years cul...
# Doc8  (0.2523, rock group korn s guitarist quits the...
# Doc9  (0.2498, doves soar to uk album summit manches...
#
#                                                  Topic8
# Doc0  (0.2068, ore costs hit global steel firms shar...
# Doc1  (0.198, car giant hit by mercedes slump a slum...
# Doc2  (0.1888, australia rates at four year high aus...
# Doc3  (0.1787, us adds more jobs than expected the u...
# Doc4  (0.1764, air china in $1bn london listing chin...
# Doc5  (0.1746, dollar hovers around record lows the ...
# Doc6  (0.1739, strong dollar  call halts slide the u...
# Doc7  (0.1724, qwest may spark mci bidding war us ph...
# Doc8  (0.1691, hariri killing hits beirut shares sha...
# Doc9  (0.1686, consumer spending lifts us growth us ...
#
# ----------------->Document-topic table for model 4:
#
#                                                  Topic0  \
# Doc0  (0.1443, more power to the people says hp the ...
# Doc1  (0.1443, more power to the people says hp the ...
# Doc2  (0.139, tv s future down the phone line intern...
# Doc3  (0.1386, roundabout continues nostalgia trip t...
# Doc4  (0.1373, qwest may spark mci bidding war us ph...
# Doc5  (0.1352, china  ripe  for media explosion asia...
# Doc6  (0.1328, gamers could drive high-definition tv...
# Doc7  (0.1317, hollywood ready for oscars night holl...
# Doc8  (0.13, karachi stocks hit historic high the ka...
# Doc9  (0.1298, internet boom for gift shopping cyber...
#
#                                                  Topic1  \
# Doc0  (0.21, kilroy launches  veritas  party ex-bbc ...
# Doc1  (0.179, blair ready to call election tony blai...
# Doc2  (0.1789, eu referendum question unveiled the q...
# Doc3  (0.1764, could rivalry overshadow election  to...
# Doc4  (0.1733, blair looks to election campaign tony...
# Doc5  (0.1705, ukip s secret weapon  by any measure ...
# Doc6  (0.1703, child access law shake-up planned par...
# Doc7  (0.1703, child access laws shake-up parents wh...
# Doc8  (0.1701, brown to outline presidency goals nex...
# Doc9  (0.1695, brown targets oaps and homebuyers gor...
#
#                                                  Topic2
# Doc0  (0.193, a november to remember last saturday  ...
# Doc1  (0.1842, britain boosted by holmes double athl...
# Doc2  (0.1821, lions blow to world cup winners briti...
# Doc3  (0.182, wales hails new superstar one game int...
# Doc4  (0.1813, lions blow to world cup stars british...
# Doc5  (0.1798, celts savour grand slam prospect the ...
# Doc6  (0.1776, white prepared for battle tough-scrum...
# Doc7  (0.1758, mourinho plots impressive course chel...
# Doc8  (0.1753, what now for kelly holmes  last april...
# Doc9  (0.1702, gb select holmes for double bid kelly...
#
# ----------------->Document-topic table for model 5:
#
#                                                  Topic0  \
# Doc0  (0.3272, blair pledges unity to labour mps ton...
# Doc1  (0.3171, blair stresses prosperity goals tony ...
# Doc2  (0.3134, blair and brown criticised by mps lab...
# Doc3  (0.3082, blair labour s longest-serving pm ton...
# Doc4  (0.3055, labour mp praises tory campaign the c...
# Doc5  (0.2987, brown outlines third term vision gord...
# Doc6  (0.2987, brown outlines third term vision gord...
# Doc7  (0.293, brown  proud of economy record  gordon...
# Doc8  (0.2918, howard taunts blair over splits tony ...
# Doc9  (0.2904, labour seeks to quell feud talk labou...
#
#                                                  Topic1  \
# Doc0  (0.2574, mourinho plots impressive course chel...
# Doc1  (0.2541, desailly backs blues revenge trip mar...
# Doc2  (0.2495, mourinho defiant on chelsea form chel...
# Doc3  (0.2384, gallas sees two-horse race chelsea s ...
# Doc4  (0.2336, mourinho takes swipe at arsenal chels...
# Doc5  (0.2336, chelsea hold arsenal a gripping game ...
# Doc6  (0.2268, english clubs make euro history all f...
# Doc7  (0.2253, adriano s chelsea link rejected adria...
# Doc8  (0.223, gerrard plays down european hopes stev...
# Doc9  (0.2206, bridge could miss rest of season chel...
#
#                                                  Topic2  \
# Doc0  (0.3216, spirit awards hail sideways the comed...
# Doc1  (0.3183, sideways dominates spirit awards the ...
# Doc2  (0.3044, aviator and vera take bafta glory hol...
# Doc3  (0.2981, bafta to hand out movie honours movie...
# Doc4  (0.2929, vera drake s bafta triumph hope at th...
# Doc5  (0.2928, foxx and swank win us awards jamie fo...
# Doc6  (0.292, foxx and swank take actors awards jami...
# Doc7  (0.2842, british stars denied major oscars bri...
# Doc8  (0.2836, wine comedy wins critics  award quirk...
# Doc9  (0.2773, aviator wins top globes accolades the...
#
#                                                  Topic3  \
# Doc0  (0.2045, ore costs hit global steel firms shar...
# Doc1  (0.1959, car giant hit by mercedes slump a slu...
# Doc2  (0.1831, australia rates at four year high aus...
# Doc3  (0.1779, qwest may spark mci bidding war us ph...
# Doc4  (0.1757, air china in $1bn london listing chin...
# Doc5  (0.1731, us adds more jobs than expected the u...
# Doc6  (0.1693, shares hit by ms drug suspension shar...
# Doc7  (0.1684, dollar hovers around record lows the ...
# Doc8  (0.1664, hariri killing hits beirut shares sha...
# Doc9  (0.1663, strong dollar  call halts slide the u...
#
#                                                  Topic4  \
# Doc0  (0.3115, mobile music challenges  ipod age  no...
# Doc1  (0.3022, mobiles  not media players yet  mobil...
# Doc2  (0.3022, mobiles  not media players yet  mobil...
# Doc3  (0.2927, looks and music to drive mobiles mobi...
# Doc4  (0.2927, looks and music to drive mobiles mobi...
# Doc5  (0.2762, mobiles rack up 20 years of use mobil...
# Doc6  (0.2762, mobiles rack up 20 years of use mobil...
# Doc7  (0.272, half of uk s mobiles  go online  multi...
# Doc8  (0.2704, friends fear  with lost mobiles peopl...
# Doc9  (0.2576, mobile gig aims to rock 3g forget abo...
#
#                                                  Topic5
# Doc0  (0.3273, celts savour grand slam prospect the ...
# Doc1  (0.3096, ireland 19-13 england ireland consign...
# Doc2  (0.3076, bell set for england debut bath prop ...
# Doc3  (0.3058, castaignede fires laporte warning for...
# Doc4  (0.3018, preview: ireland v england (sun) lans...
# Doc5  (0.2919, a november to remember last saturday ...
# Doc6  (0.2847, england given tough sevens draw engla...
# Doc7  (0.2796, dominici backs lacklustre france wing...
# Doc8  (0.2698, italy aim to rattle england italy coa...
# Doc9  (0.2686, harinordoquy suffers france axe numbe...
#
# ----------------->Document-topic table for model 6:
#
#                                                  Topic0  \
# Doc0  (0.1514, gadget growth fuels eco concerns tech...
# Doc1  (0.1512, gamers could drive high-definition tv...
# Doc2  (0.1506, the future in your pocket if you are ...
# Doc3  (0.1498, gadget market  to grow in 2005  the e...
# Doc4  (0.1498, gadget market  to grow in 2005  the e...
# Doc5  (0.1478, more power to the people says hp the ...
# Doc6  (0.1478, more power to the people says hp the ...
# Doc7  (0.1471, games win for blu-ray dvd format the ...
# Doc8  (0.1369, europe backs digital tv lifestyle how...
# Doc9  (0.1351, nintendo ds aims to touch gamers the ...
#
#                                                  Topic1  \
# Doc0  (0.2284, uk needs tax cuts  tories insist a ma...
# Doc1  (0.2244, tories urge  change at the top  tory ...
# Doc2  (0.2201, blair ready to call election tony bla...
# Doc3  (0.2132, chancellor rallies labour voters gord...
# Doc4  (0.2126, budget to set scene for election gord...
# Doc5  (0.2091, howard unveils election platform the ...
# Doc6  (0.2071, lib dems   bold  election policy char...
# Doc7  (0.206, clarke plans migrant point scheme anyo...
# Doc8  (0.2043, could rivalry overshadow election  to...
# Doc9  (0.2022, howard taunts blair over splits tony ...
#
#                                                  Topic2  \
# Doc0  (0.2268, celts savour grand slam prospect the ...
# Doc1  (0.2254, white prepared for battle tough-scrum...
# Doc2  (0.2243, lions blow to world cup winners briti...
# Doc3  (0.2229, lions blow to world cup stars british...
# Doc4  (0.2215, a november to remember last saturday ...
# Doc5  (0.2203, wales hails new superstar one game in...
# Doc6  (0.208, castaignede fires laporte warning form...
# Doc7  (0.2012, sella wants michalak recall former fr...
# Doc8  (0.2009, wales silent on grand slam talk rhys ...
# Doc9  (0.1977, wales win in rome wales secured their...
#
#                                                  Topic3  \
# Doc0  (0.2972, eastwood s baby scoops top oscars cli...
# Doc1  (0.2671, foxx and swank win us awards jamie fo...
# Doc2  (0.2621, hollywood ready for oscars night holl...
# Doc3  (0.262, foxx and swank take actors awards jami...
# Doc4  (0.261, bafta to hand out movie honours movie ...
# Doc5  (0.2544, british stars denied major oscars bri...
# Doc6  (0.2525, aviator and vera take bafta glory hol...
# Doc7  (0.2431, aviator wins top globes accolades the...
# Doc8  (0.2373, stars gear up for bafta ceremony film...
# Doc9  (0.234, surprise win for anti-bush film michae...
#
#                                                  Topic4  \
# Doc0  (0.1876, car giant hit by mercedes slump a slu...
# Doc1  (0.1869, qwest may spark mci bidding war us ph...
# Doc2  (0.1837, mci shares climb on takeover bid shar...
# Doc3  (0.1785, asia shares defy post-quake gloom ind...
# Doc4  (0.1781, mci shareholder sues to stop bid a sh...
# Doc5  (0.1725, german business confidence slides ger...
# Doc6  (0.1685, bad weather hits nestle sales a combi...
# Doc7  (0.1683, china continues rapid growth china s ...
# Doc8  (0.1664, mystery surrounds new yukos owner the...
# Doc9  (0.1651, us data sparks inflation worries whol...
#
#                                                  Topic5  \
# Doc0  (0.196, britain boosted by holmes double athle...
# Doc1  (0.1945, greek pair attend drugs hearing greek...
# Doc2  (0.1945, iaaf will contest greek decision the ...
# Doc3  (0.1862, greek pair set for hearing kostas ken...
# Doc4  (0.1795, what now for kelly holmes  last april...
# Doc5  (0.1786, holmes back on form in birmingham dou...
# Doc6  (0.1731, balco case trial date pushed back the...
# Doc7  (0.1646, stam spices up man utd encounter ac m...
# Doc8  (0.163, chepkemei hit by big ban kenya s athle...
# Doc9  (0.1619, greek sprinters suspended by iaaf gre...
#
#                                                  Topic6  \
# Doc0  (0.2337, domain system scam fear a system to m...
# Doc1  (0.2299, domain system opens door to scams a s...
# Doc2  (0.2064, rich pickings for hi-tech thieves vir...
# Doc3  (0.2021, dozens held over id fraud site twenty...
# Doc4  (0.2008, rings of steel combat net attacks gam...
# Doc5  (0.1999, us bank  loses  customer details the ...
# Doc6  (0.1995, britons fed up with net service a sur...
# Doc7  (0.1995, britons fed up with net service a sur...
# Doc8  (0.198, net fingerprints combat attacks eighty...
# Doc9  (0.1954, firefox browser takes on microsoft mi...
#
#                                                  Topic7
# Doc0  (0.2387, ten-year tragedy of missing manic ric...
# Doc1  (0.2138, black sabbath top rock album poll bla...
# Doc2  (0.2135, charity single for quake relief singe...
# Doc3  (0.2123, band aid 20 single storms to no 1 the...
# Doc4  (0.2122, prince crowned  top music earner  pri...
# Doc5  (0.2122, prince crowned  top music earner  pri...
# Doc6  (0.2082, blair buys copies of new band aid pri...
# Doc7  (0.2039, rock group korn s guitarist quits the...
# Doc8  (0.2025, portishead back after eight years cul...
# Doc9  (0.2011, new york rockers top talent poll new ...

# %%
nmf_table = PrettyTable()
nmf_table.field_names = [
    "Model Name",
    "Number Of Components",
    "Init",
    "Solver",
    "Beta Loss",
    "Random State",
    "Alpha",
    "L1 Ratio"
]

# Loop through the models
for i, nmf_model in enumerate(all_nfm_models, start=1):
    # Get the parameters
    model_name = f"Model {i}"
    n_components = nmf_model.n_components
    init = nmf_model.init
    solver = nmf_model.solver
    beta_loss = nmf_model.beta_loss
    random_state = nmf_model.random_state
    alpha = nmf_model.alpha
    l1_ratio = nmf_model.l1_ratio

    # Add a row to the table
    nmf_table.add_row([model_name, n_components, init, solver, beta_loss, random_state, alpha, l1_ratio])

# Print the table
print("\nNMF Model Details:\n")
print(nmf_table)
# Out:
# NMF Model Details:
#
# +------------+----------------------+---------+--------+------------------+--------------+-------+----------+
# | Model Name | Number Of Components |   Init  | Solver |    Beta Loss     | Random State | Alpha | L1 Ratio |
# +------------+----------------------+---------+--------+------------------+--------------+-------+----------+
# |  Model 1   |          7           |  nndsvd |   mu   |    frobenius     |      0       |  0.1  |   0.2    |
# |  Model 2   |          4           |  random |   mu   |    frobenius     |      42      |  0.01 |   0.3    |
# |  Model 3   |          9           |  random |   cd   |    frobenius     |      20      |  0.1  |   0.2    |
# |  Model 4   |          3           | nndsvda |   mu   | kullback-leibler |      42      |  0.01 |   0.4    |
# |  Model 5   |          6           |  random |   cd   |    frobenius     |      42      |  0.1  |   0.1    |
# |  Model 6   |          8           |  nndsvd |   mu   | kullback-leibler |      42      |  0.1  |   0.2    |
# +------------+----------------------+---------+--------+------------------+--------------+-------+----------+

# %%
all_nfm_transforms = []

for i, nmf_model in enumerate(all_nfm_models, start=1):
    nmf_transform = nmf_model.transform(tfidf)
    all_nfm_transforms.append(nmf_transform)

# %%
# plot_tsne(data=nmf_transform, threshold=0)

for i, nmf_transform in enumerate(all_nfm_transforms, start=1):
    plot_tsne(data=nmf_transform, threshold=0)
    plt.title(f"t-SNE Plot for Model {i}")
    plt.show()

# %%
# # calculate reconstruction error for NMF
# # lower reconstruction error indicates a better performance,
# # how well the model can reconstruct the original data from the factored matrices

for i, nmf_model in enumerate(all_nfm_models, start=1):
    reconstruction_error = nmf_model.reconstruction_err_
    print(f"Reconstruction error for nfm model {i}: {reconstruction_error}")
# Out:
# Reconstruction error for nfm model 1: 36.558143022957864
# Reconstruction error for nfm model 2: 37.11332006130039
# Reconstruction error for nfm model 3: 36.190388321244235
# Reconstruction error for nfm model 4: 204.52219440397838
# Reconstruction error for nfm model 5: 36.69054190969418
# Reconstruction error for nfm model 6: 193.90964131803625

# %%
# calculate MSE
def calculate_mse(nmf_model, vectorizer):
    reconstructed_data = np.dot (nmf_model.transform(vectorizer), nmf_model.components_)
    mse = mean_squared_error(vectorizer.toarray(), reconstructed_data)

    return mse

# %%
all_mse_scores = []

for i, nmf_model in enumerate(all_nfm_models, start=1):
    mse_score_model = calculate_mse(nmf_model, tfidf)
    all_mse_scores.append(mse_score_model)
    print(f"MSE for Model {i}: {mse_score_model}")
# Out:
# MSE for Model 1: 0.0008961089906163359
# MSE for Model 2: 0.0009244263849126298
# MSE for Model 3: 0.0008790229401319698
# MSE for Model 4: 0.0009476839592100634
# MSE for Model 5: 0.0009034872329086749
# MSE for Model 6: 0.0009069650086367609

# %% [markdown]
# # **Discussion:**

# %% [markdown]
# ## **the Best LDA model**
#
# **Discussion**
#
# Let's first read the word topic table and the document topic table of all the LDA models and understand the abstract topics.
#
# **LDA Model 1**: Topic0 and Topic1 are overlapping topics; they are movies and music, which are about entertainment.
#
# **LDA Model 2**: Topic0 is a mix of local news, international news and sports.
#
# **LDA Model 3**: Topic0 does not have a central theme in the topic. Topic1 is a mix of sports and entertainment. Topic2 is a mix of politics and international news.
#
# **LDA Model 4**: The topics are very clear. Topic0: news; Topic1: economy; Topic2: entertainment; Topic3: technology; and Topic4: sports.
#
# **LDA Model 5**: Topic0 and Topic2 are duplicated theme; they both centralized around politics.
#
# **LDA Model 6**: Topic0, Topic1, Topic2 are mixed topics on sports and technology.
#
# Looking at the T-SNE plots, LDA Model 2, LDA Model 3, LDA Model 4 and LDA Model 5 all show clear clusters with good separation between the topics. Yet the topics are spread out which means the topics appear across the corpus.
#
# After checking the word topic table and the document topic table of all the LDA models, as well as their T-SNE plots, **LDA Model 4** is the best. It successfully separates the news into a clear category of 5 different topics.

# %%
# set up the best LDa model
best_lda = lda4
best_lda_mod_name = 'lda4'

best_lda_vec = vectorizer4
best_lda_clean_vec = clean_vec4

# %%
# print the perplexity of the best LDA model
print("Perplexity of the best LDA model: {}".format(lda_dict[best_lda_mod_name]['perplexity']))
# Out:
# Perplexity of the best LDA model: 723.0339512765811

# %%
# display the word-topic table of the best LDA model
lda_dict[best_lda_mod_name]['W_df']
# Out:
#                       Topic0               Topic1              Topic2  \
# Word0        (0.0224, blair)     (0.0115, search)      (0.034, award)
# Word1         (0.017, brown)      (0.0111, share)     (0.0182, actor)
# Word2       (0.0124, howard)     (0.0093, dollar)     (0.0131, chart)
# Word3   (0.0094, chancellor)      (0.0092, virus)     (0.0125, oscar)
# Word4  (0.009, conservative)   (0.0082, software)     (0.0111, album)
# Word5      (0.0067, liberal)  (0.0073, microsoft)   (0.0106, actress)
# Word6   (0.0066, parliament)       (0.007, rates)     (0.0099, movie)
# Word7     (0.0066, democrat)      (0.0069, costs)  (0.0098, festival)
# Word8     (0.0059, minister)      (0.0066, stock)     (0.0093, prize)
# Word9      (0.0055, kennedy)   (0.0064, consumer)  (0.0087, producer)
#
#                     Topic3              Topic4
# Word0     (0.0344, mobile)   (0.0139, ireland)
# Word1   (0.0146, computer)    (0.0135, france)
# Word2  (0.0136, broadband)  (0.0128, champion)
# Word3     (0.0135, gadget)     (0.0128, wales)
# Word4   (0.0135, consumer)    (0.0112, injury)
# Word5      (0.0134, phone)     (0.0111, coach)
# Word6   (0.0119, download)    (0.011, chelsea)
# Word7     (0.01, software)     (0.0103, sport)
# Word8       (0.01, camera)     (0.0083, title)
# Word9      (0.0093, apple)      (0.008, rugby)

# %%
# display the document-topic table of the best LDA model
lda_dict[best_lda_mod_name]['H_df']
# Out:
#                                                  Topic0  \
# Doc0  (0.9928, anti-terror plan faces first test pla...
# Doc1  (0.9919, howard unveils tory asylum plans tory...
# Doc2  (0.9919, terror suspects face house arrest uk ...
# Doc3  (0.9911, howard denies split over id cards mic...
# Doc4  (0.9911, howard denies split over id cards mic...
# Doc5  (0.9909, howard taunts blair over splits tony ...
# Doc6  (0.9908, asylum children to face returns the u...
# Doc7  (0.9907, no more concessions  on terror charle...
# Doc8  (0.9906, blair defends terror law changes the ...
# Doc9  (0.99, voters  don t trust politicians  eight ...
#
#                                                  Topic1  \
# Doc0  (0.9911, security scares spark browser fix mic...
# Doc1  (0.9897, microsoft debuts security tools micro...
# Doc2  (0.9888, car giant hit by mercedes slump a slu...
# Doc3  (0.9884, asian banks halt dollar s slide the d...
# Doc4  (0.988, us trade deficit widens sharply the ga...
# Doc5  (0.9875, french suitor holds lse meeting europ...
# Doc6  (0.9873, domain system scam fear a system to m...
# Doc7  (0.9871, domain system opens door to scams a s...
# Doc8  (0.987, microsoft sets sights on spyware windo...
# Doc9  (0.9869, asia shares defy post-quake gloom ind...
#
#                                                  Topic2  \
# Doc0  (0.9965, critics back aviator for oscars marti...
# Doc1  (0.9924, eastwood s baby scoops top oscars cli...
# Doc2  (0.9916, aviator and vera take bafta glory hol...
# Doc3  (0.9912, british stars denied major oscars bri...
# Doc4  (0.9898, bafta to hand out movie honours movie...
# Doc5  (0.989, new york rockers top talent poll new y...
# Doc6  (0.989, stars shine on bafta red carpet hollyw...
# Doc7  (0.9888, foxx and swank take actors awards jam...
# Doc8  (0.9886, foxx and swank win us awards jamie fo...
# Doc9  (0.9884, new york rockers top talent poll new ...
#
#                                                  Topic3  \
# Doc0  (0.9959, apple laptop is  greatest gadget  the...
# Doc1  (0.995, apple laptop is  greatest gadget  the ...
# Doc2  (0.9934, broadband set to revolutionise tv bt ...
# Doc3  (0.9934, tv s future down the phone line inter...
# Doc4  (0.993, mobiles  not media players yet  mobile...
# Doc5  (0.993, mobiles  not media players yet  mobile...
# Doc6  (0.9929, nintendo ds aims to touch gamers the ...
# Doc7  (0.9929, mobile music challenges  ipod age  no...
# Doc8  (0.9928, doors open at biggest gadget fair tho...
# Doc9  (0.9928, doors open at biggest gadget fair tho...
#
#                                                  Topic4
# Doc0  (0.9952, nadal puts spain 2-0 up result: nadal...
# Doc1  (0.9934, britain boosted by holmes double athl...
# Doc2  (0.9926, wales win in rome wales secured their...
# Doc3  (0.9924, celts savour grand slam prospect the ...
# Doc4  (0.9922, holmes back on form in birmingham dou...
# Doc5  (0.9921, a november to remember last saturday ...
# Doc6  (0.992, mourinho plots impressive course chels...
# Doc7  (0.9919, ireland 17-12 south africa ronan o ga...
# Doc8  (0.9914, ireland 19-13 england ireland consign...
# Doc9  (0.9909, henman to face saulnier test british ...

# %%
# iteractive plot with pca biplot and histogram

# use the appropriate code depending on the environment
lda_plot = pyLDAvis.sklearn.prepare(best_lda, best_lda_clean_vec, best_lda_vec, R=10)
#lda_plot = pyLDAvis.lda_model.prepare(best_lda, best_lda_clean_vec, best_lda_vec, R=10)

pyLDAvis.display(lda_plot)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el342131401703165975844073969750"></div>
# <script type="text/javascript">
#
# var ldavis_el342131401703165975844073969750_data = {"mdsDat": {"x": [0.0500377440068603, -0.14762165683391051, 0.2252254817879603, -0.19849163189072175, 0.070850062929812], "y": [-0.16043027233363508, -0.11485737674787846, -0.03423674685009266, 0.08593805908313516, 0.22358633684847062], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [24.202879865536975, 22.790293727739446, 20.428466950568687, 17.466738562320216, 15.11162089383467]}, "tinfo": {"Term": ["mobile", "award", "blair", "actor", "brown", "broadband", "champion", "gadget", "phone", "ireland", "liberal", "conservative", "immigration", "asylum", "blair", "poverty", "commons", "sentence", "manifesto", "democrat", "chancellor", "parliament", "brown", "howard", "kennedy", "minister", "airline", "google", "virus", "investor", "stock", "shareholder", "trading", "deutsche", "spyware", "economist", "exchange", "export", "search", "profits", "share", "dollar", "rates", "costs", "software", "microsoft", "consumer", "champion", "chelsea", "coach", "injury", "yukos", "arsenal", "olympic", "championship", "robinson", "grand", "rugby", "irish", "ireland", "france", "wales", "sport", "williams", "title", "mobile", "broadband", "gadget", "phone", "apple", "devices", "camera", "console", "portable", "handset", "gaming", "technology", "download", "computer", "network", "consumer", "software", "actor", "chart", "oscar", "actress", "festival", "comedy", "nomination", "aviator", "nominate", "theatre", "musical", "award", "album", "prize", "movie", "singer", "producer"], "Freq": [445.0, 391.0, 405.0, 203.0, 322.0, 176.0, 193.0, 175.0, 173.0, 227.0, 118.94357542699494, 160.19480157863347, 90.19404011040503, 78.04179549989415, 399.8871964144504, 56.557668334711465, 86.14014734734836, 47.83428770091985, 50.743686595440984, 117.42312372480367, 167.04623678412293, 117.45248679632418, 303.160403445601, 221.43407881124452, 99.0594248790446, 105.82621844836909, 106.5644210691379, 104.85544381827049, 154.90162226237956, 89.3179757822335, 110.99435757382236, 91.77980668944421, 63.06596902807114, 64.18473015376452, 52.632204316212345, 67.41890990126217, 103.50573163621425, 95.43318173126634, 193.53441387451628, 105.11814910965117, 186.48099340223595, 155.50256095650997, 117.89622486830856, 115.35180613410081, 138.43501404944465, 122.63564778793122, 107.18184284128739, 193.10878929589109, 166.23534189814637, 167.61608547707417, 168.13712587124334, 113.55700718648632, 110.91340957368121, 103.66524694677157, 102.71734433016685, 91.08023186103416, 90.02873643573896, 120.28038331071915, 99.3309190955045, 208.7206030473366, 203.6475104506, 192.77294450393623, 155.1168264689767, 117.7675084566847, 125.48837919070765, 443.5997531578305, 175.66383639196596, 174.2348958655329, 172.1031714425393, 119.80507389042238, 106.96277590042483, 128.72821765450107, 90.04257682964113, 75.18577926564247, 74.1882791204178, 92.49007624435812, 81.40817435965687, 153.49131131475477, 188.7015501914877, 110.23125320682796, 173.80595390279382, 128.75078609366994, 202.3459360615155, 146.28259479875175, 139.65785698169168, 118.3901875778732, 109.20234377253101, 92.64970234919365, 92.32264407794189, 75.68479108388328, 65.42072723367755, 74.0848167240315, 78.45596506506016, 378.5122412560232, 123.26848126935936, 103.11037077440163, 110.41851593158216, 96.75084553771991, 97.08148412240878], "Total": [445.0, 391.0, 405.0, 203.0, 322.0, 176.0, 193.0, 175.0, 173.0, 227.0, 119.77170205457898, 161.50612034222232, 90.9893646285637, 78.85081835351552, 405.3463911217256, 57.376835815114774, 87.47116998950203, 48.6399064699557, 51.638172755824584, 119.50593867305568, 170.59484485348275, 120.73251764125837, 322.712539819298, 241.12649719945946, 102.1290725427602, 118.03807992267808, 107.35498395629324, 105.75048408856615, 156.38413399594558, 90.20810596239821, 112.27844208257977, 92.8635492782817, 63.86980059884632, 65.02772297763126, 53.420333900670066, 68.46197926612838, 105.51745558836278, 97.7928431626879, 203.21522435189036,  ...

# %% [markdown]
# **Topics Found in pyLDAvis**
# * Topic 1: politics
# * Topic 2: business
# * Topic 3: sports
# * Topic 4: technology
# * Topic 5: entertainment

# %% [markdown]
# ## **the Best NMF model**
#
# Our best model nmf_model5, has 1000 features using the TF-IDF method and has 6 components.
#
# The model's reconstruction error is 36.69, which means it has a good capacity to reconstruct the original data from factored matrices. The MSE nmf_model5 is 0.000903, a basic number that means precision in the approximation of the original data.
# We see no overlapping when we use word cloud, the topics are clear, and well-separated.
# The model nmf_model5 has a low reconstruction error and MSE, Model 5 effectively captures and represents the underlying structure of the data.
# Clear separation with topics covering mobile, music, software, and political figures.
# Distinct and well-defined topics.
#
# **NMF Model 1**
# Good separation per topic.
# Topics include mobile, music, awards, and political figures.
# Model 1 demonstrates a relatively low reconstruction error and MSE, indicating effective data reconstruction.
#
# **NMF Model 2**
# Good separation per topic
# Topics cover political figures, sports, and awards.
# Despite a slightly higher reconstruction error, Model 2 maintains a moderate MSE. The data reconstruction is generally accurate.
#
# **NMF Model 3**
# Has the lowest MSE
# Despite a lower MSE, there is no good separation by topic. Topics are mixed
#
# **NMF Model 4**
# High MSE and reconstruction errors suggest less effective data reconstruction.
# Some overlap and less distinct separation between topics.
#
# **NMF Model 6**
# High MSE and reconstruction errors suggest less effective data reconstruction.
# Slight overlap, but the topics are well-differentiated.

# %%
def plot_word_clouds_for_model(W_df, model_index):
    for topic_idx in range(W_df.shape[1]):
        word_weights = {word: weight for (weight, word) in W_df[f'Topic{topic_idx}']}
        wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_weights)
        plt.figure(figsize=(4, 4))
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis('off')
        plt.title(f'Word Cloud for Topic {topic_idx + 1} (Model {model_index + 1})')
        plt.show()

# %%
# set up the best NMF model
best_nmf = nmf_model5
best_nmf_mod_name = 'nmf5'

# %%
model_index = 4  # index starts with 0
W_df_model4, _ = results_nmf[model_index]

plot_word_clouds_for_model(W_df_model4, model_index)

# %%
# display the word-topic table of the best NMF model
best_nmf_index = 4
best_nmf_W_df, _ = results_nmf[best_nmf_index]
print(f"\n--------------> Word topic tables for the best NMF model:\n")
print(best_nmf_W_df)
# Out:
# --------------> Word topic tables for the best NMF model:
#
#                        Topic0                  Topic1                Topic2  \
# Word0        (0.0482, labour)       (0.0345, chelsea)       (0.0582, award)
# Word1         (0.0396, blair)      (0.0274, champion)        (0.029, actor)
# Word2         (0.0333, brown)       (0.0232, arsenal)       (0.0272, oscar)
# Word3        (0.0188, howard)     (0.0159, liverpool)  (0.0192, nomination)
# Word4    (0.0183, chancellor)       (0.0144, olympic)     (0.0191, actress)
# Word5       (0.0129, britain)        (0.0135, madrid)       (0.0147, prize)
# Word6  (0.0129, conservative)        (0.0129, injury)     (0.014, ceremony)
# Word7       (0.0117, kennedy)         (0.0122, title)      (0.0139, comedy)
# Word8       (0.0098, liberal)      (0.0111, ferguson)     (0.0134, aviator)
# Word9      (0.0094, democrat)  (0.0106, championship)    (0.0124, category)
#
#                   Topic3              Topic4              Topic5
# Word0    (0.0138, share)    (0.0451, mobile)   (0.0582, england)
# Word1   (0.011, analyst)     (0.0245, music)     (0.0366, wales)
# Word2   (0.0109, dollar)     (0.0178, phone)   (0.0319, ireland)
# Word3  (0.0103, profits)  (0.0155, software)     (0.028, france)
# Word4    (0.0085, stock)    (0.0143, gadget)    (0.0232, nation)
# Word5   (0.0073, figure)  (0.0135, computer)  (0.0226, robinson)
# Word6    (0.0071, rates)  (0.013, microsoft)     (0.0225, rugby)
# Word7     (0.007, costs)  (0.0108, download)      (0.021, coach)
# Word8   (0.0067, export)    (0.0106, camera)  (0.0199, scotland)
# Word9  (0.0067, deficit)  (0.0106, consumer)    (0.0155, injury)

# %%
# display the document-topic table of the best NMF model
_, best_nmf_H_df = results_nmf[best_nmf_index]
print(f"\n-----------------> Document-topic table for the best NMF model:\n")
print(best_nmf_H_df)
# Out:
# -----------------> Document-topic table for the best NMF model:
#
#                                                  Topic0  \
# Doc0  (0.3272, blair pledges unity to labour mps ton...
# Doc1  (0.3171, blair stresses prosperity goals tony ...
# Doc2  (0.3134, blair and brown criticised by mps lab...
# Doc3  (0.3082, blair labour s longest-serving pm ton...
# Doc4  (0.3055, labour mp praises tory campaign the c...
# Doc5  (0.2987, brown outlines third term vision gord...
# Doc6  (0.2987, brown outlines third term vision gord...
# Doc7  (0.293, brown  proud of economy record  gordon...
# Doc8  (0.2918, howard taunts blair over splits tony ...
# Doc9  (0.2904, labour seeks to quell feud talk labou...
#
#                                                  Topic1  \
# Doc0  (0.2574, mourinho plots impressive course chel...
# Doc1  (0.2541, desailly backs blues revenge trip mar...
# Doc2  (0.2495, mourinho defiant on chelsea form chel...
# Doc3  (0.2384, gallas sees two-horse race chelsea s ...
# Doc4  (0.2336, mourinho takes swipe at arsenal chels...
# Doc5  (0.2336, chelsea hold arsenal a gripping game ...
# Doc6  (0.2268, english clubs make euro history all f...
# Doc7  (0.2253, adriano s chelsea link rejected adria...
# Doc8  (0.223, gerrard plays down european hopes stev...
# Doc9  (0.2206, bridge could miss rest of season chel...
#
#                                                  Topic2  \
# Doc0  (0.3216, spirit awards hail sideways the comed...
# Doc1  (0.3183, sideways dominates spirit awards the ...
# Doc2  (0.3044, aviator and vera take bafta glory hol...
# Doc3  (0.2981, bafta to hand out movie honours movie...
# Doc4  (0.2929, vera drake s bafta triumph hope at th...
# Doc5  (0.2928, foxx and swank win us awards jamie fo...
# Doc6  (0.292, foxx and swank take actors awards jami...
# Doc7  (0.2842, british stars denied major oscars bri...
# Doc8  (0.2836, wine comedy wins critics  award quirk...
# Doc9  (0.2773, aviator wins top globes accolades the...
#
#                                                  Topic3  \
# Doc0  (0.2045, ore costs hit global steel firms shar...
# Doc1  (0.1959, car giant hit by mercedes slump a slu...
# Doc2  (0.1831, australia rates at four year high aus...
# Doc3  (0.1779, qwest may spark mci bidding war us ph...
# Doc4  (0.1757, air china in $1bn london listing chin...
# Doc5  (0.1731, us adds more jobs than expected the u...
# Doc6  (0.1693, shares hit by ms drug suspension shar...
# Doc7  (0.1684, dollar hovers around record lows the ...
# Doc8  (0.1664, hariri killing hits beirut shares sha...
# Doc9  (0.1663, strong dollar  call halts slide the u...
#
#                                                  Topic4  \
# Doc0  (0.3115, mobile music challenges  ipod age  no...
# Doc1  (0.3022, mobiles  not media players yet  mobil...
# Doc2  (0.3022, mobiles  not media players yet  mobil...
# Doc3  (0.2927, looks and music to drive mobiles mobi...
# Doc4  (0.2927, looks and music to drive mobiles mobi...
# Doc5  (0.2762, mobiles rack up 20 years of use mobil...
# Doc6  (0.2762, mobiles rack up 20 years of use mobil...
# Doc7  (0.272, half of uk s mobiles  go online  multi...
# Doc8  (0.2704, friends fear  with lost mobiles peopl...
# Doc9  (0.2576, mobile gig aims to rock 3g forget abo...
#
#                                                  Topic5
# Doc0  (0.3273, celts savour grand slam prospect the ...
# Doc1  (0.3096, ireland 19-13 england ireland consign...
# Doc2  (0.3076, bell set for england debut bath prop ...
# Doc3  (0.3058, castaignede fires laporte warning for...
# Doc4  (0.3018, preview: ireland v england (sun) lans...
# Doc5  (0.2919, a november to remember last saturday ...
# Doc6  (0.2847, england given tough sevens draw engla...
# Doc7  (0.2796, dominici backs lacklustre france wing...
# Doc8  (0.2698, italy aim to rattle england italy coa...
# Doc9  (0.2686, harinordoquy suffers france axe numbe...

# %% [markdown]
# # **Conclusion:**
#
# Overall, the best model is LDA model 4, with features 1250 words and parameters disregarding words that appear in 10% of the records and those that appear in less than 15 records.
#
# In comparison to the optimal NMF model, it was observed that the best NMF model identifies six topics, with topics 1 and 5 exhibiting an overlap in the sports category. This indicates an issue of over-cooked topics.
#
# Quantitatively, LDA Model 4 achieved the second-lowest perplexity score at 723, surpassing the lowest-scoring yet overly specific Model 5 (700).
#
# Qualitatively, LDA model 4's pyLDAvis bubbles have a reasonable size which indicates that each topic is relatively balanced across the entire dataset and distinct circles which reflect the distinct topics. The T-SNE plot demonstrates that there are 5 distinct clusters.
#
# The best model accurately classifies news articles into 5 categories which align with the 5 topics in the original dataset. This model can be a valuable tool for personalized news feeds, targeted advertising, and trend analysis. Stakeholders can leverage this model to gain insights into new trends, optimize decision-making and enhance their user experiences in applications such as personalized news feeds.
